# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %run init.py
# Out:
# /home/antonis/anaconda2/envs/snorkel27clone/lib/python2.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from snorkel.annotations import save_marginals

# %%
from snorkel.learning import GenerativeModelLinear

# %%
from snorkel.lf_helpers import *
import pickle,glob

# %%
import pandas as pd
from MLutils import cohen_kappa_score

# %%
from MLutils import diversity_heatmap, merge_pickles_pred_dicts

# %%
# needed to train the LSTM here
train = session.query(REGULATOR).filter(REGULATOR.split == 0).all()
dev = session.query(REGULATOR).filter(REGULATOR.split == 1).all()
test = session.query(REGULATOR).filter(REGULATOR.split == 2).all()
unlab = session.query(REGULATOR).filter(REGULATOR.split == 3).all()

# %%
# make sure unmapped cands are gone

# %%
from sqlalchemy import  any_,or_,and_

# %%
#create list of unmapped cands to drop
to_drop = []
for k in range(3):
    query = session.query(REGULATOR).filter(and_(REGULATOR.split==k,~REGULATOR.gold_labels.any()))
    print 'Adding %i candidates from split=%i in to_drop list'%(query.count(), k)
    to_drop.extend(map(lambda x: x.id,query.all()))
# Out:
# Adding 0 candidates from split=0 in to_drop list
# Adding 0 candidates from split=1 in to_drop list
# Adding 0 candidates from split=2 in to_drop list

# %%
# #drop unmapped cands
# query = session.query(Candidate).filter(Candidate.id.in_(to_drop))
# print query.count()
# query.delete(synchronize_session=False)
# session.commit()

# %% [markdown]
# # Retrieve results and pick models

# %%
# results_dict = merge_pickles_pred_dicts(glob.glob('ml_predictions/*.pkl'), 
#                                         f1_threshold=0.49,
#                                         list_substr=['results_dict,','minFreq=3','_'],
#                                         best_model=True,
#                                        )

# %%
with open("ml_predictions/12models_clustering_outerdistances.pickle", 'rb') as f:
    results_dict = pickle.load(f)
print 'Loaded:\n',
results_dict.keys()
# Out:
# Loaded:
# ['results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear',
#  'results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear',
#  'RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,max_sent_length=64_biLSTM',
#  'fasttext_fasttext',
#  'results_dict,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(0, 3),LSA100_NeuralNet(10,10)',
#  'results_dict,lemmas,RuS,CV_,bin_,minFreq=1,_ngrams=(1, 1),LSA100_LogisticRegression',
#  'results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(1, 1),LSA100_RandomForestClassifier',
#  'results_dict,trim=5,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(0, 3),LSA100_SVC_linear',
#  'results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngrams=(1, 1),LSA100_RandomForestClassifier',
#  'results_dict,trim=5,lemmas,RuS,CV_,bin_,minFreq=1,_stopw=english,_ngrams=(1, 1),LSA100_LogisticRegression',
#  'results_dict,ShortDepPath,RuS,TfIdf_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear',
#  'results_dict,lemmas,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(1, 1),LSA100_RandomForestClassifier']

# %%
selected_models = results_dict.keys()

# %%
# set(results_dict[results_dict.keys()[0]])

# %%
# unlab_keys0 = set(results_dict[results_dict.keys()[0]]['label_unlab_prob_dict'].keys())
# #check model performance
# for model_name in results_dict.keys():
#     print '\n',results_dict[model_name]['f1+'], model_name
#     print 'Keys matching: ',unlab_keys0 == set(results_dict[model_name]['label_unlab_prob_dict'].keys())
#     result_prob = [results_dict[model_name]['label_unlab_prob_dict'][cid] for cid in sorted(results_dict[model_name]['label_unlab_prob_dict'].keys(), reverse=True)]
#     result_bin = [0 if prob<=0.5 else 1 for prob in result_prob]
#     print result[:10]
#     print result_bin[-1110:-1000]
    
    
#     print result_unlab_binary01[-1110:-1000]
    
# #     print result_bin == result_unlab_binary01
    
    
#     # deal with this shit later.... nice confidence there man!
# #     pd.Series(result).hist()
# #     plt.plot()

# %%
# result = [results_dict[key] for model_name in sorted(results_dict.keys(), reverse=True)]

# %% [markdown]
# ** heuristic developed for model selection **
#
# (replaced by classifier selection.ipynb )

# %%
# model_names = sorted(results_dict.keys())
# cohens_df = pd.DataFrame(index=model_names, columns=model_names)

# %%
# evaluate_on= 'label_val_binary'
# for i,model1 in enumerate(cohens_df.index):
#     for j,model2 in enumerate(cohens_df.columns):
#         if i==j:
#             cohens_df.iloc[i,j] = 0
#         else:
#             cohens_df.iloc[i,j] = cohen_kappa_score(results_dict[model1][evaluate_on],results_dict[model2][evaluate_on])

# %%
# cohens_df.mean().sort_values().index[0]

# %%
# selected_models = ['trim=5,RuS,CV,bin,,stopw=english,LSA100_SVC_rbf_C=500',
#                   'lemmas,RuS,TfIdf,,stopw=english_SVC_rbf_C=500'
                  
#                   ]
# candidate_model = ['trim=5,lemmas,RuS,TfIdf,,stopw=english_LogisticRegression',]


# max([cohens_df.ix[candidate_model, selected_model].values[0] for selected_model in selected_models])

# %%
# def select_models(cohens_df, diversity_threshold , f1_threshold=0):
#     selected_models = [cohens_df.mean().sort_values().index[0]]
#     for candidate_model in cohens_df.mean().sort_values().index[1:]:
#         #check whether all cohens kappas are < threshold
#         if max([cohens_df.ix[candidate_model, selected_model] for selected_model in selected_models])<diversity_threshold:
#             selected_models.append(candidate_model)
#     return selected_models

# %%
# selected_models = select_models(cohens_df, diversity_threshold = 0.2, )

# selected_models
# # results_dict1 = {}
# # for key in selected_models:
# #     results_dict1[key]=results_dict[key]

# %%
from MLutils import diversity_matrix, reduce_results_dict

# %%
from sklearn.metrics import accuracy_score, cohen_kappa_score

# %%
metric = accuracy_score

mean = diversity_matrix(
    results_dict,
    metric=accuracy_score,
    diagonal_key=None
).mean().mean()

diversity_heatmap(results_dict, 
                  metric=metric, diagonal_key='f1+', 
                  evaluate_on = "label_unlab_prob+",
                  title='Diversity heatmap for %i models picked by clustering (mean(%s)=%.2f)'%(
                      len(results_dict),metric.__name__, mean) )

# %%
# lowest_model_name = cohens_df.mean().idxmin()
# print cohens_df.mean().idxmin() , cohens_df.mean().min()

# %% [markdown]
# # Load predicted labels from classifiers

# %%
from snorkel.annotations import LabelAnnotator

# %% [markdown]
# ** with label generator **

# %%
# Include the results for validation data
def signal_annotator_unlab_val(c):
    """A generator over the different (worker_id, label_id) pairs for a Tweet."""
    for model in results_dict.keys():

        #hack to convert labels to -1,1....
        try:
            yield model, (results_dict[model]['label_unlab_prob+'][c.id] >= 0.5)*2-1
        except:
            yield model, (results_dict[model]['label_val_prob+'][c.id] >= 0.5)*2-1


labeler = LabelAnnotator(label_generator=signal_annotator_unlab_val)

# %%
# %time L_train = labeler.apply(split=3, parallelism=6)
# L_train
# Out:
# Clearing existing...
# Running UDF...
# CPU times: user 14min 26s, sys: 35.7 s, total: 15min 2s
# Wall time: 57min 11s
# <79400x12 sparse matrix of type '<type 'numpy.int64'>'
# 	with 952800 stored elements in Compressed Sparse Row format>

# %%
# # dump vote matrix to disk
# with open("L_train_12_models", 'wb') as f:
#     pickle.dump(L_train, f)

# %%
#open from disk
with open("L_train_12_models", 'rb') as f:
    L_train = pickle.load(f)

# %%
# load from developer set & labels
L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)
L_gold_dev
print ''
L_dev = labeler.apply_existing(split=1, parallelism=6)
L_dev
# Out:
# Clearing existing...
# Running UDF...
# <3230x12 sparse matrix of type '<type 'numpy.int64'>'
# 	with 38760 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Balance L_train

# %%
(pd.Series(list(map(lambda x:x[0].item(),L_train.mean(axis=1))))>=0.5).value_counts()
# Out:
# False    74296
# True      5104
# dtype: int64

# %%
74296/5104.
# Out:
# 14.556426332288401

# %%
#this would be with unweighted voting

pd.Series(list(map(lambda x:x[0].item(),L_train.mean(axis=1)))).hist(bins=41)
plt.title('Unweighted voting for 12 classifiers')
# Out:
# Text(0.5,1,'Unweighted voting for 12 classifiers')

# %% [markdown]
# ## Randomly delete some negative values (about 50% of them).
# ->
# denoising doesn't work leaving code here for future reference though

# %%
# Randomly delete some negative values (about 50% of them). 
# However, this creates a bias towards positive class 
#  + denoising doesn't work

# %%
# neg_L_train = L_train==-1
# pos_L_train = L_train==1

# %%
# create a (random) mask

# %%
# from scipy.sparse import rand

# rand_csr = rand(L_train.shape[0], L_train.shape[1], density=0.5, format='csr')
# rand_csr.data[:] = 1

# %%
# L_train_subsampled = L_train.multiply(neg_L_train.multiply(rand_csr) + pos_L_train)

# %% [markdown]
# ## Undersample examples having mean(votes) <0.5

# %%
L_train_lbls = list(map(lambda x: int(x[0].item()), L_train.mean(axis=1)>=0.5))

# %%
(L_train.mean(axis=1)>=0.5).astype(int)
# Out:
# matrix([[False],
#         [False],
#         [False],
#         ...,
#         [False],
#         [False],
#         [False]], dtype=object)

# %%
from MLutils import balance_candidates
from utils import delete_from_csr

# %%
ind_us, lbls_us = balance_candidates(indices, lbls)
indices = [i for i in range(L_train.shape[0])]
ind_to_del = list(set(indices).difference(set(ind_us)))

# %%
L_train_us = delete_from_csr(L_train,row_indices=ind_to_del)

# %%
L_train.shape
# Out:
# (79400, 12)

# %%
L_train_us.shape
# Out:
# (10208, 12)

# %% [markdown]
# # Start denoising

# %%
# see how many LF vote on how many examples & with how many other LFs there are votes on common examples
L_train.lf_stats(session)
# Out:
#                                                      j  Coverage  Overlaps  \
# results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1...   0       1.0       1.0
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...   1       1.0       1.0
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...   2       1.0       1.0
# fasttext_fasttext                                    3       1.0       1.0
# results_dict,RuS,TfIdf_,minFreq=1,_stopw=englis...   4       1.0       1.0
# results_dict,lemmas,RuS,CV_,bin_,minFreq=1,_ngr...   5       1.0       1.0
# results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1...   6       1.0       1.0
# results_dict,trim=5,RuS,TfIdf_,minFreq=1,_stopw...   7       1.0       1.0
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...   8       1.0       1.0
# results_dict,trim=5,lemmas,RuS,CV_,bin_,minFreq...   9       1.0       1.0
# results_dict,ShortDepPath,RuS,TfIdf_,minFreq=1,...  10       1.0       1.0
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_stopw...  11       1.0       1.0
#
#                                                     Conflicts
# results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1...   0.642922
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...   0.642922
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...   0.642922
# fasttext_fasttext                                    0.642922
# results_dict,RuS,TfIdf_,minFreq=1,_stopw=englis...   0.642922
# results_dict,lemmas,RuS,CV_,bin_,minFreq=1,_ngr...   0.642922
# results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1...   0.642922
# results_dict,trim=5,RuS,TfIdf_,minFreq=1,_stopw...   0.642922
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...   0.642922
# results_dict,trim=5,lemmas,RuS,CV_,bin_,minFreq...   0.642922
# results_dict,ShortDepPath,RuS,TfIdf_,minFreq=1,...   0.642922
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_stopw...   0.642922

# %%
# Find dependencies between LFs

from snorkel.learning.structure import DependencySelector
ds = DependencySelector()
deps1 = ds.select(L_train_us, threshold=0.1)
deps2 = ds.select(L_train_us, threshold=0.2)
deps3 = ds.select(L_train_us, threshold=0.3)
deps05 = ds.select(L_train_us, threshold=0.05)
deps01 = ds.select(L_train_us, threshold=0.01)

print len(deps01),len(deps05),len(deps1),len(deps2),len(deps3)
# Out:
# 66 51 35 11 4

# %%
# Generate all possible dependencies with threshold from 0 to 0.15
all_deps = [ds.select(L_train_us, threshold=thresh) for thresh in np.array(range(5,14))/100.]
print list(map(lambda x: len(x) ,all_deps))
all_deps = list(np.unique(all_deps)) # delete duplicates for gridsearch
print list(map(lambda x: len(x) ,all_deps))
# Out:
# [51, 46, 41, 36, 35, 35, 34, 32, 30]
# [30, 32, 34, 35, 36, 41, 46, 51]

# %% [markdown]
# # Train the generative model with altered $\beta \simeq 0.38 $

# %%
# %%time
### Normal training

# actual training of the gen. model
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel(lf_propensity=True, class_prior=False )
gen_model.train(
    L_train_us, decay=0.95, step_size=0.1/L_train.shape[0], reg_param=1e-6,  threads = 6,
    deps=deps,
)
# Out:
# Inferred cardinality: 2
# CPU times: user 37.8 s, sys: 71.6 ms, total: 37.9 s
# Wall time: 16 s

# %%
gen_model.learned_lf_stats()
# Out:
#     Accuracy  Coverage  Precision    Recall
# 0   0.920615    0.8125   0.950539  0.742202
# 1   0.912340    0.7974   0.938179  0.726357
# 2   0.914920    0.8110   0.938644  0.744842
# 3   0.915871    0.8166   0.944155  0.747813
# 4   0.929098    0.8279   0.952712  0.768114
# 5   0.929640    0.8286   0.950627  0.775375
# 6   0.934440    0.8374   0.954281  0.785443
# 7   0.926912    0.8223   0.952234  0.763327
# 8   0.921424    0.8145   0.949029  0.749794
# 9   0.931904    0.8209   0.953322  0.771910
# 10  0.918053    0.8054   0.945616  0.740386
# 11  0.918337    0.8180   0.944410  0.745833

# %%
train_marginals_us = gen_model.marginals(L_train_us)

# %%
plt.hist(train_marginals_us, bins=20)
plt.title('Histogram of marginals with candidates undersampled before GM ')
plt.show()

# %% [markdown]
# ### Hyperparameter search

# %%
from snorkel.learning import RandomSearch, GenerativeModel, GridSearch

# %%
param_ranges = { # parameters for the train function of the GenerativeModel
    'step_size' : [1e-2,1e-3,1e-4],
    'decay' : [0.95,0.99],
    'epochs' : [300],
    'reg_param': [1e-50 ,1e-100 ,1e-200 ],
    'deps': all_deps
}

model_class_params = {  # parameters for the GenerativeModel
    'lf_propensity': [True]
}

searcher = RandomSearch(GenerativeModel, param_ranges,  L_train_us, model_class_params = model_class_params , n=80 )

# %%
# %%time
gen_model, run_stats = searcher.fit(L_dev, L_gold_dev, n_threads=7 )
run_stats['#deps'] = list(map(lambda x: len(run_stats.deps[x]), run_stats.index)) # save # deps to identify 'deps'
# Out:
# Loading data...
# Launching jobs...
# Inferred cardinality: 2
# Inferred cardinality: 2
# Inferred cardinality: 2
# Inferred cardinality: 2
# Inferred cardinality: 2
# Inferred cardinality: 2
# Inferred cardinality: 2
# [GenerativeModel] Model saved as <GenerativeModel_6>.
# [GenerativeModel] Model saved as <GenerativeModel_1>.
# [GenerativeModel] Model saved as <GenerativeModel_4>.
# [GenerativeModel] Model saved as <GenerativeModel_0>.
# [GenerativeModel] Model saved as <GenerativeModel_2>.
# [GenerativeModel] Model saved as <GenerativeModel_3>.
# Inferred cardinality: 2
# Model 6 Done; score: 0.587398796246
# Inferred cardinality: 2
# Model 4 Done; score: 0.0297170460751
# Inferred cardinality: 2
# Model 1 Done; score: 0.0305899967466
# Inferred cardinality: 2
# Model 0 Done; score: 0.401593928553
# Inferred cardinality: 2
# Model 2 Done; score: 0.841874887733
# Inferred cardinality: 2
# Model 3 Done; score: 0.739640627013
# [GenerativeModel] Model saved as <GenerativeModel_5>.
# Inferred cardinality: 2
# Model 5 Done; score: 0.51697737142
# [GenerativeModel] Model saved as <GenerativeModel_8>.
# [GenerativeModel] Model saved as <GenerativeModel_7>.
# [GenerativeModel] Model saved as <GenerativeModel_10>.
# [GenerativeModel] Model saved as <GenerativeModel_9>.
# [GenerativeModel] Model saved as <GenerativeModel_11>.
# Inferred cardinality: 2
# Model 8 Done; score: 0.739640627013
# Inferred cardinality: 2
# Model 10 Done; score: 0.112411228204
# Inferred cardinality: 2
# Model 7 Done; score: 0.799761964895
# [GenerativeModel] Model saved as <GenerativeModel_12>.
# Inferred cardinality: 2
# Model 9 Done; score: 0.0305899967466
# Inferred cardinality: 2
# Model 11 Done; score: 0.0305899967466
# [GenerativeModel] Model saved as <GenerativeModel_13>.
# Inferred cardinality: 2
# Model 12 Done; score: 0.0335528249677
# Inferred cardinality: 2
# Model 13 Done; score: 0.0365215605619
# [GenerativeModel] Model saved as <GenerativeModel_17>.
# Inferred cardinality: 2
# Model 17 Done; score: 0.489687496807
# [GenerativeModel] Model saved as <GenerativeModel_16>.
# [GenerativeModel] Model saved as <GenerativeModel_19>.
# [GenerativeModel] Model saved as <GenerativeModel_14>.
# [GenerativeModel] Model saved as <GenerativeModel_18>.
# [GenerativeModel] Model saved as <GenerativeModel_15>.
# Inferred cardinality: 2
# Model 14 Done; score: 0.112411228204
# Inferred cardinality: 2
# Model 16 Done; score: 0.0290532496728
# Inferred cardinality: 2
# Model 19 Done; score: 0.030456232432
# Inferred cardinality: 2
# Model 18 Done; score: 0.0290532496728
# Inferred cardinality: 2
# Model 15 Done; score: 0.392399858545
# [GenerativeModel] Model saved as <GenerativeModel_20>.
# Inferred cardinality: 2
# Model 20 Done; score: 0.562641655472
# [GenerativeModel] Model saved as <GenerativeModel_21>.
# Inferred cardinality: 2
# Model 21 Done; score: 0.377156287197
# [GenerativeModel] Model saved as <GenerativeModel_24>.
# [GenerativeModel] Model saved as <GenerativeModel_22>.
# [GenerativeModel] Model saved as <GenerativeModel_23>.
# [GenerativeModel] Model saved as <GenerativeModel_26>.
# [GenerativeModel] Model saved as <GenerativeModel_25>.
# Inferred cardinality: 2
# Model 22 Done; score: 0.0350558383814
# Inferred cardinality: 2
# Model 24 Done; score: 0.770770887387
# Inferred cardinality: 2
# Model 23 Done; score: 0.0297170460751
# Inferred cardinality: 2
# Model 26 Done; score: 1.00915101536
# Inferred cardinality: 2
# Model 25 Done; score: 0.0350558383814
# [GenerativeModel] Model saved as <GenerativeModel_27>.
# Inferred cardinality: 2
# Model 27 Done; score: 0.841874887733
# [GenerativeModel] Model saved as <GenerativeModel_28>.
# Inferred cardinality: 2
# Model 28 Done; score: 0.0335528249677
# [GenerativeModel] Model saved as <GenerativeModel_30>.
# [GenerativeModel] Model saved as <GenerativeModel_29>.
# [GenerativeModel] Model saved as <GenerativeModel_32>.
# [GenerativeModel] Model saved as <GenerativeModel_31>.
# [GenerativeModel] Model saved as <GenerativeModel_33>.
# Inferred cardinality: 2
# Model 30 Done; score: 0.0290532496728
# Inferred cardinality: 2
# Model 32 Done; score: 0.0305991673167
# Inferred cardinality: 2
# Model 29 Done; score: 0.46083452143
# Inferred cardinality: 2
# Model 33 Done; score: 0.772523672631
# Inferred cardinality: 2
# Model 31 Done; score: 0.0307783752792
# [GenerativeModel] Model saved as <GenerativeModel_34>.
# Inferred cardinality: 2
# Model 34 Done; score: 0.554737655381
# [GenerativeModel] Model saved as <GenerativeModel_35>.
# Inferred cardinality: 2
# Model 35 Done; score: 0.0335528249677
# [GenerativeModel] Model saved as <GenerativeModel_37>.
# [GenerativeModel] Model saved as <GenerativeModel_38>.
# Inferred cardinality: 2
# Model 37 Done; score: 0.0297170460751
# [GenerativeModel] Model saved as <GenerativeModel_39>.
# [GenerativeModel] Model saved as <GenerativeModel_40>.
# [GenerativeModel] Model saved as <GenerativeModel_36>.
# Inferred cardinality: 2
# Model 39 Done; score: 0.362972842478
# Inferred cardinality: 2
# Model 38 Done; score: 1.02837764049
# Inferred cardinality: 2
# Model 40 Done; score: 0.0322117821263
# Inferred cardinality: 2
# Model 36 Done; score: 0.0343674166148
# [GenerativeModel] Model saved as <GenerativeModel_41>.
# Inferred cardinality: 2
# Model 41 Done; score: 0.489687496807
# [GenerativeModel] Model saved as <GenerativeModel_43>.
# [GenerativeModel] Model saved as <GenerativeModel_42>.
# Inferred cardinality: 2
# Model 43 Done; score: 0.401593928553
# Inferred cardinality: 2
# Model 42 Done; score: 1.03609152427
# [GenerativeModel] Model saved as <GenerativeModel_44>.
# [GenerativeModel] Model saved as <GenerativeModel_46>.
# [GenerativeModel] Model saved as <GenerativeModel_45>.
# Inferred cardinality: 2
# Model 44 Done; score: 0.0365215605619
# Inferred cardinality: 2
# Model 46 Done; score: 0.0284168382018
# [GenerativeModel] Model saved as <GenerativeModel_47>.
# Inferred cardinality: 2
# Model 45 Done; score: 0.772523672631
# Inferred cardinality: 2
# Model 47 Done; score: 0.739640627013
# [GenerativeModel] Model saved as <GenerativeModel_48>.
# [GenerativeModel] Model saved as <GenerativeModel_49>.
# [GenerativeModel] Model saved as <GenerativeModel_50>.
# Inferred cardinality: 2
# Model 48 Done; score: 0.0377941973103
# Inferred cardinality: 2
# Model 49 Done; score: 0.0284168382018
# Inferred cardinality: 2
# Model 50 Done; score: 1.03609152427
# [GenerativeModel] Model saved as <GenerativeModel_54>.
# Inferred cardinality: 2
# Model 54 Done; score: 0.0322117821263
# [GenerativeModel] Model saved as <GenerativeModel_51>.
# [GenerativeModel] Model saved as <GenerativeModel_53>.
# [GenerativeModel] Model saved as <GenerativeModel_52>.
# Inferred cardinality: 2
# Model 51 Done; score: 0.739640627013
# Inferred cardinality: 2
# Model 53 Done; score: 1.02837764049
# Inferred cardinality: 2
# Model 52 Done; score: 0.51697737142
# [GenerativeModel] Model saved as <GenerativeModel_55>.
# [GenerativeModel] Model saved as <GenerativeModel_58>.
# [GenerativeModel] Model saved as <GenerativeModel_57>.
# Inferred cardinality: 2
# Model 55 Done; score: 0.904934431526
# [GenerativeModel] Model saved as <GenerativeModel_56>.
# Inferred cardinality: 2
# Model 58 Done; score: 0.0307783752792
# Inferred cardinality: 2
# Model 57 Done; score: 0.0322117821263
# Inferred cardinality: 2
# Model 56 Done; score: 0.0335528249677
# [GenerativeModel] Model saved as <GenerativeModel_59>.
# [GenerativeModel] Model saved as <GenerativeModel_60>.
# Inferred cardinality: 2
# Model 59 Done; score: 0.739640627013
# [GenerativeModel] Model saved as <GenerativeModel_61>.
# Inferred cardinality: 2
# Model 60 Done; score: 0.0335528249677
# [GenerativeModel] Model saved as <GenerativeModel_62>.
# Inferred cardinality: 2
# Model 61 Done; score: 0.587398796246
# Inferred cardinality: 2
# Model 62 Done; score: 0.0322117821263
# [GenerativeModel] Model saved as <GenerativeModel_65>.
# [GenerativeModel] Model saved as <GenerativeModel_64>.
# [GenerativeModel] Model saved as <GenerativeModel_63>.
# Inferred cardinality: 2
# Model 64 Done; score: 0.0297267283034
# Inferred cardinality: 2
# Model 65 Done; score: 0.915460304686
# Inferred cardinality: 2
# Model 63 Done; score: 0.144460241725
# [GenerativeModel] Model saved as <GenerativeModel_67>.
# [GenerativeModel] Model saved as <GenerativeModel_68>.
# [GenerativeModel] Model saved as <GenerativeModel_66>.
# Inferred cardinality: 2
# Model 67 Done; score: 0.0343674166148
# Inferred cardinality: 2
# Model 68 Done; score: 0.697455504149
# Inferred cardinality: 2
# Model 66 Done; score: 0.51697737142
# [GenerativeModel] Model saved as <GenerativeModel_69>.
# [GenerativeModel] Model saved as <GenerativeModel_70>.
# [GenerativeModel] Model saved as <GenerativeModel_71>.
# Inferred cardinality: 2
# Model 70 Done; score: 0.46083452143
# Inferred cardinality: 2
# Model 69 Done; score: 0.67667359732
# [GenerativeModel] Model saved as <GenerativeModel_72>.
# Inferred cardinality: 2
# Model 71 Done; score: 0.0365215605619
# Inferred cardinality: 2
# Model 72 Done; score: 0.0365215605619
# [GenerativeModel] Model saved as <GenerativeModel_73>.
# Model 73 Done; score: 0.697455504149
# [GenerativeModel] Model saved as <GenerativeModel_74>.
# [GenerativeModel] Model saved as <GenerativeModel_75>.
# Model 74 Done; score: 0.0297170460751
# Model 75 Done; score: 0.770770887387
# [GenerativeModel] Model saved as <GenerativeModel_77>.
# [GenerativeModel] Model saved as <GenerativeModel_76>.
# Model 77 Done; score: 0.0290532496728
# Model 76 Done; score: 0.0377941973103
# [GenerativeModel] Model saved as <GenerativeModel_79>.
# [GenerativeModel] Model saved as <GenerativeModel_78>.
# Model 79 Done; score: 0.799761964895
# Model 78 Done; score: 0.587398796246
# [GenerativeModel] Model <GenerativeModel_42> loaded.
# [GenerativeModel] Model saved as <GenerativeModel_best>.
# CPU times: user 328 ms, sys: 181 ms, total: 509 ms
# Wall time: 1h 7min 19s

# %%
run_stats
# Out:
#     Model  epochs  step_size      reg_param  \
# 43     42     300     0.0001  1.000000e-100
# 50     50     300     0.0001  1.000000e-200
# 38     38     300     0.0001  1.000000e-100
# 53     53     300     0.0001  1.000000e-200
# 25     26     300     0.0010  1.000000e-200
# 64     65     300     0.0001   1.000000e-50
# 55     55     300     0.0001  1.000000e-200
# 27     27     300     0.0001   1.000000e-50
# 4       2     300     0.0001  1.000000e-100
# 9       7     300     0.0010  1.000000e-200
# 78     79     300     0.0010   1.000000e-50
# 46     45     300     0.0100  1.000000e-100
# 32     33     300     0.0100  1.000000e-100
# 23     24     300     0.0100  1.000000e-100
# 75     75     300     0.0100  1.000000e-200
# 7       8     300     0.0001  1.000000e-100
# 59     59     300     0.0001   1.000000e-50
# 5       3     300     0.0001  1.000000e-100
# 52     51     300     0.0001   1.000000e-50
# 47     47     300     0.0001   1.000000e-50
# 67     68     300     0.0001  1.000000e-200
# 73     73     300     0.0001  1.000000e-200
# 70     69     300     0.0010  1.000000e-100
# 0       6     300     0.0001  1.000000e-100
# 61     61     300     0.0001   1.000000e-50
# 79     78     300     0.0001  1.000000e-200
# 20     20     300     0.0001   1.000000e-50
# 34     34     300     0.0010  1.000000e-200
# 6       5     300     0.0001   1.000000e-50
# 54     52     300     0.0001   1.000000e-50
# ..    ...     ...        ...            ...
# 22     22     300     0.0100  1.000000e-200
# 40     36     300     0.0100   1.000000e-50
# 66     67     300     0.0100  1.000000e-200
# 28     28     300     0.0100  1.000000e-100
# 35     35     300     0.0100  1.000000e-200
# 58     56     300     0.0100  1.000000e-100
# 60     60     300     0.0100   1.000000e-50
# 12     12     300     0.0100   1.000000e-50
# 62     62     300     0.0010   1.000000e-50
# 51     54     300     0.0010   1.000000e-50
# 57     57     300     0.0010   1.000000e-50
# 39     40     300     0.0010   1.000000e-50
# 33     31     300     0.0100  1.000000e-100
# 56     58     300     0.0100   1.000000e-50
# 30     32     300     0.0010   1.000000e-50
# 11     11     300     0.0010  1.000000e-200
# 2       1     300     0.0010   1.000000e-50
# 10      9     300     0.0010  1.000000e-100
# 17     19     300     0.0010  1.000000e-200
# 63     64     300     0.0100   1.000000e-50
# 36     37     300     0.0100  1.000000e-100
# 74     74     300     0.0100  1.000000e-100
# 24     23     300     0.0100  1.000000e-100
# 1       4     300     0.0100   1.000000e-50
# 18     18     300     0.0100  1.000000e-100
# 29     30     300     0.0100   1.000000e-50
# 76     77     300     0.0100   1.000000e-50
# 16     16     300     0.0100  1.000000e-200
# 45     46     300     0.0100  1.000000e-200
# 49     49     300     0.0100   1.000000e-50
#
#                                                  deps  decay     Prec.  \
# 43  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.609502
# 50  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.609502
# 38  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.616845
# 53  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.616845
# 25  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.646722
# 64  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.615195
# 55  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.606061
# 27  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.561404
# 4   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.561404
# 9   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.641611
# 78  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.641611
# 46  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.642424
# 32  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.642424
# 23  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.647887
# 75  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.647887
# 7   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.542312
# 59  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.542312
# 5   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.542312
# 52  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.542312
# 47  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.542312
# 67  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.537786
# 73  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.537786
# 70  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.524986
# 0   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.521320
# 61  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.521320
# 79  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.521320
# 20  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.503542
# 34  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.553787
# 6   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.500000
# 54  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.500000
# ..                                                ...    ...       ...
# 22  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.151828
# 40  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.156125
# 66  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.156125
# 28  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.152600
# 35  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.152600
# 58  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.152600
# 60  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.152600
# 12  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.152600
# 62  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.145800
# 51  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.145800
# 57  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.145800
# 39  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.145800
# 33  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.147961
# 56  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.147961
# 30  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.142403
# 11  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.141767
# 2   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.141767
# 10  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.141767
# 17  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.143175
# 63  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.145212
# 36  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.142448
# 74  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.142448
# 24  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.142448
# 1   {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.95  0.142448
# 18  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.146249
# 29  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.146249
# 76  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.146249
# 16  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.146249
# 45  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.143583
# 49  {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...   0.99  0.143583
#
#         Rec.       F-1  #deps
# 43 -0.588270  1.036092     34
# 50 -0.588270  1.036092     34
# 38 -0.599823  1.028378     32
# 53 -0.599823  1.028378     32
# 25 -0.640857  1.009151     34
# 64 -0.672006  0.915460     30
# 55 -0.669729  0.904934     32
# 27 -0.666849  0.841875     34
# 4  -0.666849  0.841875     34
# 9  -0.802252  0.799762     36
# 78 -0.802252  0.799762     36
# 46 -0.831592  0.772524     35
# 32 -0.831592  0.772524     35
# 23 -0.840571  0.770771     34
# 75 -0.840571  0.770771     34
# 7  -0.733211  0.739641     35
# 59 -0.733211  0.739641     35
# 5  -0.733211  0.739641     35
# 52 -0.733211  0.739641     35
# 47 -0.733211  0.739641     35
# 67 -0.771068  0.697456     36
# 73 -0.771068  0.697456     36
# 70 -0.775834  0.676674     36
# 0  -0.887507  0.587399     41
# 61 -0.887507  0.587399     41
# 79 -0.887507  0.587399     41
# 20 -0.894960  0.562642     46
# 34 -0.998287  0.554738     46
# 6  -0.967160  0.516977     51
# 54 -0.967160  0.516977     51
# ..       ...       ...    ...
# 22 -4.331020  0.035056     41
# 40 -4.542810  0.034367     51
# 66 -4.542810  0.034367     51
# 28 -4.548065  0.033553     46
# 35 -4.548065  0.033553     46
# 58 -4.548065  0.033553     46
# 60 -4.548065  0.033553     46
# 12 -4.548065  0.033553     46
# 62 -4.526304  0.032212     35
# 51 -4.526304  0.032212     35
# 57 -4.526304  0.032212     35
# 39 -4.526304  0.032212     35
# 33 -4.807297  0.030778     35
# 56 -4.807297  0.030778     35
# 30 -4.653821  0.030599     34
# 11 -4.634434  0.030590     32
# 2  -4.634434  0.030590     32
# 10 -4.634434  0.030590     32
# 17 -4.701018  0.030456     30
# 63 -4.884911  0.029727     30
# 36 -4.793489  0.029717     32
# 74 -4.793489  0.029717     32
# 24 -4.793489  0.029717     32
# 1  -4.793489  0.029717     32
# 18 -5.033819  0.029053     32
# 29 -5.033819  0.029053     32
# 76 -5.033819  0.029053     32
# 16 -5.033819  0.029053     32
# 45 -5.052752  0.028417     34
# 49 -5.052752  0.028417     34
#
# [80 rows x 10 columns]

# %%
for idx in run_stats.index:
    print run_stats.loc[idx]
    gen_model.load('GenerativeModel_%i'%run_stats.loc[idx,'Model'], save_dir='checkpoints/grid_search/')
    train_marginals_us = gen_model.marginals(L_train_us)
    plt.hist(train_marginals_us, bins=20)
    plt.title('Histogram of marginals with candidates undersampled before GM ')
    plt.show()
    print '\n\n'
# Out:
# Model                                                       42
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.609502
# Rec.                                                  -0.58827
# F-1                                                    1.03609
# #deps                                                       34
# Name: 43, dtype: object
# [GenerativeModel] Model <GenerativeModel_42> loaded.
# Model                                                       50
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.609502
# Rec.                                                  -0.58827
# F-1                                                    1.03609
# #deps                                                       34
# Name: 50, dtype: object
# [GenerativeModel] Model <GenerativeModel_50> loaded.
# Model                                                       38
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.616845
# Rec.                                                 -0.599823
# F-1                                                    1.02838
# #deps                                                       32
# Name: 38, dtype: object
# [GenerativeModel] Model <GenerativeModel_38> loaded.
# Model                                                       53
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.616845
# Rec.                                                 -0.599823
# F-1                                                    1.02838
# #deps                                                       32
# Name: 53, dtype: object
# [GenerativeModel] Model <GenerativeModel_53> loaded.
# Model                                                       26
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.646722
# Rec.                                                 -0.640857
# F-1                                                    1.00915
# #deps                                                       34
# Name: 25, dtype: object
# [GenerativeModel] Model <GenerativeModel_26> loaded.
# Model                                                       65
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.615195
# Rec.                                                 -0.672006
# F-1                                                    0.91546
# #deps                                                       30
# Name: 64, dtype: object
# [GenerativeModel] Model <GenerativeModel_65> loaded.
# Model                                                       55
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.606061
# Rec.                                                 -0.669729
# F-1                                                   0.904934
# #deps                                                       32
# Name: 55, dtype: object
# [GenerativeModel] Model <GenerativeModel_55> loaded.
# Model                                                       27
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.561404
# Rec.                                                 -0.666849
# F-1                                                   0.841875
# #deps                                                       34
# Name: 27, dtype: object
# [GenerativeModel] Model <GenerativeModel_27> loaded.
# Model                                                        2
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.561404
# Rec.                                                 -0.666849
# F-1                                                   0.841875
# #deps                                                       34
# Name: 4, dtype: object
# [GenerativeModel] Model <GenerativeModel_2> loaded.
# Model                                                        7
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.641611
# Rec.                                                 -0.802252
# F-1                                                   0.799762
# #deps                                                       36
# Name: 9, dtype: object
# [GenerativeModel] Model <GenerativeModel_7> loaded.
# Model                                                       79
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.641611
# Rec.                                                 -0.802252
# F-1                                                   0.799762
# #deps                                                       36
# Name: 78, dtype: object
# [GenerativeModel] Model <GenerativeModel_79> loaded.
# Model                                                       45
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.642424
# Rec.                                                 -0.831592
# F-1                                                   0.772524
# #deps                                                       35
# Name: 46, dtype: object
# [GenerativeModel] Model <GenerativeModel_45> loaded.
# Model                                                       33
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.642424
# Rec.                                                 -0.831592
# F-1                                                   0.772524
# #deps                                                       35
# Name: 32, dtype: object
# [GenerativeModel] Model <GenerativeModel_33> loaded.
# Model                                                       24
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.647887
# Rec.                                                 -0.840571
# F-1                                                   0.770771
# #deps                                                       34
# Name: 23, dtype: object
# [GenerativeModel] Model <GenerativeModel_24> loaded.
# Model                                                       75
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.647887
# Rec.                                                 -0.840571
# F-1                                                   0.770771
# #deps                                                       34
# Name: 75, dtype: object
# [GenerativeModel] Model <GenerativeModel_75> loaded.
# Model                                                        8
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.542312
# Rec.                                                 -0.733211
# F-1                                                   0.739641
# #deps                                                       35
# Name: 7, dtype: object
# [GenerativeModel] Model <GenerativeModel_8> loaded.
# Model                                                       59
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.542312
# Rec.                                                 -0.733211
# F-1                                                   0.739641
# #deps                                                       35
# Name: 59, dtype: object
# [GenerativeModel] Model <GenerativeModel_59> loaded.
# Model                                                        3
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.542312
# Rec.                                                 -0.733211
# F-1                                                   0.739641
# #deps                                                       35
# Name: 5, dtype: object
# [GenerativeModel] Model <GenerativeModel_3> loaded.
# Model                                                       51
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.542312
# Rec.                                                 -0.733211
# F-1                                                   0.739641
# #deps                                                       35
# Name: 52, dtype: object
# [GenerativeModel] Model <GenerativeModel_51> loaded.
# Model                                                       47
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.542312
# Rec.                                                 -0.733211
# F-1                                                   0.739641
# #deps                                                       35
# Name: 47, dtype: object
# [GenerativeModel] Model <GenerativeModel_47> loaded.
# Model                                                       68
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.537786
# Rec.                                                 -0.771068
# F-1                                                   0.697456
# #deps                                                       36
# Name: 67, dtype: object
# [GenerativeModel] Model <GenerativeModel_68> loaded.
# Model                                                       73
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.537786
# Rec.                                                 -0.771068
# F-1                                                   0.697456
# #deps                                                       36
# Name: 73, dtype: object
# [GenerativeModel] Model <GenerativeModel_73> loaded.
# Model                                                       69
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.524986
# Rec.                                                 -0.775834
# F-1                                                   0.676674
# #deps                                                       36
# Name: 70, dtype: object
# [GenerativeModel] Model <GenerativeModel_69> loaded.
# Model                                                        6
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                  0.52132
# Rec.                                                 -0.887507
# F-1                                                   0.587399
# #deps                                                       41
# Name: 0, dtype: object
# [GenerativeModel] Model <GenerativeModel_6> loaded.
# Model                                                       61
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                  0.52132
# Rec.                                                 -0.887507
# F-1                                                   0.587399
# #deps                                                       41
# Name: 61, dtype: object
# [GenerativeModel] Model <GenerativeModel_61> loaded.
# Model                                                       78
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                  0.52132
# Rec.                                                 -0.887507
# F-1                                                   0.587399
# #deps                                                       41
# Name: 79, dtype: object
# [GenerativeModel] Model <GenerativeModel_78> loaded.
# Model                                                       20
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.503542
# Rec.                                                  -0.89496
# F-1                                                   0.562642
# #deps                                                       46
# Name: 20, dtype: object
# [GenerativeModel] Model <GenerativeModel_20> loaded.
# Model                                                       34
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.553787
# Rec.                                                 -0.998287
# F-1                                                   0.554738
# #deps                                                       46
# Name: 34, dtype: object
# [GenerativeModel] Model <GenerativeModel_34> loaded.
# Model                                                        5
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                      0.5
# Rec.                                                  -0.96716
# F-1                                                   0.516977
# #deps                                                       51
# Name: 6, dtype: object
# [GenerativeModel] Model <GenerativeModel_5> loaded.
# Model                                                       52
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                      0.5
# Rec.                                                  -0.96716
# F-1                                                   0.516977
# #deps                                                       51
# Name: 54, dtype: object
# [GenerativeModel] Model <GenerativeModel_52> loaded.
# Model                                                       66
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                      0.5
# Rec.                                                  -0.96716
# F-1                                                   0.516977
# #deps                                                       51
# Name: 68, dtype: object
# [GenerativeModel] Model <GenerativeModel_66> loaded.
# Model                                                       41
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.511206
# Rec.                                                  -1.04394
# F-1                                                   0.489687
# #deps                                                       35
# Name: 41, dtype: object
# [GenerativeModel] Model <GenerativeModel_41> loaded.
# Model                                                       17
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.511206
# Rec.                                                  -1.04394
# F-1                                                   0.489687
# #deps                                                       35
# Name: 14, dtype: object
# [GenerativeModel] Model <GenerativeModel_17> loaded.
# Model                                                       29
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                  0.54292
# Rec.                                                  -1.17812
# F-1                                                   0.460835
# #deps                                                       41
# Name: 31, dtype: object
# [GenerativeModel] Model <GenerativeModel_29> loaded.
# Model                                                       70
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                  0.54292
# Rec.                                                  -1.17812
# F-1                                                   0.460835
# #deps                                                       41
# Name: 69, dtype: object
# [GenerativeModel] Model <GenerativeModel_70> loaded.
# Model                                                        0
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                  0.47267
# Rec.                                                  -1.17699
# F-1                                                   0.401594
# #deps                                                       36
# Name: 3, dtype: object
# [GenerativeModel] Model <GenerativeModel_0> loaded.
# Model                                                       43
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                  0.47267
# Rec.                                                  -1.17699
# F-1                                                   0.401594
# #deps                                                       36
# Name: 42, dtype: object
# [GenerativeModel] Model <GenerativeModel_43> loaded.
# Model                                                       15
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.492364
# Rec.                                                  -1.25475
# F-1                                                     0.3924
# #deps                                                       51
# Name: 19, dtype: object
# [GenerativeModel] Model <GenerativeModel_15> loaded.
# Model                                                       21
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.467314
# Rec.                                                  -1.23905
# F-1                                                   0.377156
# #deps                                                       51
# Name: 21, dtype: object
# [GenerativeModel] Model <GenerativeModel_21> loaded.
# Model                                                       39
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.445748
# Rec.                                                  -1.22805
# F-1                                                   0.362973
# #deps                                                       46
# Name: 37, dtype: object
# [GenerativeModel] Model <GenerativeModel_39> loaded.
# Model                                                       63
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.195799
# Rec.                                                  -1.35538
# F-1                                                    0.14446
# #deps                                                       46
# Name: 65, dtype: object
# [GenerativeModel] Model <GenerativeModel_63> loaded.
# Model                                                       14
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.164602
# Rec.                                                  -1.46429
# F-1                                                   0.112411
# #deps                                                       51
# Name: 15, dtype: object
# [GenerativeModel] Model <GenerativeModel_14> loaded.
# Model                                                       10
# epochs                                                     300
# step_size                                               0.0001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.164602
# Rec.                                                  -1.46429
# F-1                                                   0.112411
# #deps                                                       51
# Name: 8, dtype: object
# [GenerativeModel] Model <GenerativeModel_10> loaded.
# Model                                                       76
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.146234
# Rec.                                                  -3.86921
# F-1                                                  0.0377942
# #deps                                                       41
# Name: 77, dtype: object
# [GenerativeModel] Model <GenerativeModel_76> loaded.
# Model                                                       48
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.146234
# Rec.                                                  -3.86921
# F-1                                                  0.0377942
# #deps                                                       41
# Name: 48, dtype: object
# [GenerativeModel] Model <GenerativeModel_48> loaded.
# Model                                                       71
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.140935
# Rec.                                                  -3.85896
# F-1                                                  0.0365216
# #deps                                                       30
# Name: 71, dtype: object
# [GenerativeModel] Model <GenerativeModel_71> loaded.
# Model                                                       44
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.140935
# Rec.                                                  -3.85896
# F-1                                                  0.0365216
# #deps                                                       30
# Name: 44, dtype: object
# [GenerativeModel] Model <GenerativeModel_44> loaded.
# Model                                                       13
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.140935
# Rec.                                                  -3.85896
# F-1                                                  0.0365216
# #deps                                                       30
# Name: 13, dtype: object
# [GenerativeModel] Model <GenerativeModel_13> loaded.
# Model                                                       72
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.140935
# Rec.                                                  -3.85896
# F-1                                                  0.0365216
# #deps                                                       30
# Name: 72, dtype: object
# [GenerativeModel] Model <GenerativeModel_72> loaded.
# Model                                                       25
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.151828
# Rec.                                                  -4.33102
# F-1                                                  0.0350558
# #deps                                                       41
# Name: 26, dtype: object
# [GenerativeModel] Model <GenerativeModel_25> loaded.
# Model                                                       22
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.151828
# Rec.                                                  -4.33102
# F-1                                                  0.0350558
# #deps                                                       41
# Name: 22, dtype: object
# [GenerativeModel] Model <GenerativeModel_22> loaded.
# Model                                                       36
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.156125
# Rec.                                                  -4.54281
# F-1                                                  0.0343674
# #deps                                                       51
# Name: 40, dtype: object
# [GenerativeModel] Model <GenerativeModel_36> loaded.
# Model                                                       67
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.156125
# Rec.                                                  -4.54281
# F-1                                                  0.0343674
# #deps                                                       51
# Name: 66, dtype: object
# [GenerativeModel] Model <GenerativeModel_67> loaded.
# Model                                                       28
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1526
# Rec.                                                  -4.54807
# F-1                                                  0.0335528
# #deps                                                       46
# Name: 28, dtype: object
# [GenerativeModel] Model <GenerativeModel_28> loaded.
# Model                                                       35
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1526
# Rec.                                                  -4.54807
# F-1                                                  0.0335528
# #deps                                                       46
# Name: 35, dtype: object
# [GenerativeModel] Model <GenerativeModel_35> loaded.
# Model                                                       56
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1526
# Rec.                                                  -4.54807
# F-1                                                  0.0335528
# #deps                                                       46
# Name: 58, dtype: object
# [GenerativeModel] Model <GenerativeModel_56> loaded.
# Model                                                       60
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1526
# Rec.                                                  -4.54807
# F-1                                                  0.0335528
# #deps                                                       46
# Name: 60, dtype: object
# [GenerativeModel] Model <GenerativeModel_60> loaded.
# Model                                                       12
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1526
# Rec.                                                  -4.54807
# F-1                                                  0.0335528
# #deps                                                       46
# Name: 12, dtype: object
# [GenerativeModel] Model <GenerativeModel_12> loaded.
# Model                                                       62
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1458
# Rec.                                                   -4.5263
# F-1                                                  0.0322118
# #deps                                                       35
# Name: 62, dtype: object
# [GenerativeModel] Model <GenerativeModel_62> loaded.
# Model                                                       54
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1458
# Rec.                                                   -4.5263
# F-1                                                  0.0322118
# #deps                                                       35
# Name: 51, dtype: object
# [GenerativeModel] Model <GenerativeModel_54> loaded.
# Model                                                       57
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1458
# Rec.                                                   -4.5263
# F-1                                                  0.0322118
# #deps                                                       35
# Name: 57, dtype: object
# [GenerativeModel] Model <GenerativeModel_57> loaded.
# Model                                                       40
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                   0.1458
# Rec.                                                   -4.5263
# F-1                                                  0.0322118
# #deps                                                       35
# Name: 39, dtype: object
# [GenerativeModel] Model <GenerativeModel_40> loaded.
# Model                                                       31
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.147961
# Rec.                                                   -4.8073
# F-1                                                  0.0307784
# #deps                                                       35
# Name: 33, dtype: object
# [GenerativeModel] Model <GenerativeModel_31> loaded.
# Model                                                       58
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.147961
# Rec.                                                   -4.8073
# F-1                                                  0.0307784
# #deps                                                       35
# Name: 56, dtype: object
# [GenerativeModel] Model <GenerativeModel_58> loaded.
# Model                                                       32
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.142403
# Rec.                                                  -4.65382
# F-1                                                  0.0305992
# #deps                                                       34
# Name: 30, dtype: object
# [GenerativeModel] Model <GenerativeModel_32> loaded.
# Model                                                       11
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.141767
# Rec.                                                  -4.63443
# F-1                                                    0.03059
# #deps                                                       32
# Name: 11, dtype: object
# [GenerativeModel] Model <GenerativeModel_11> loaded.
# Model                                                        1
# epochs                                                     300
# step_size                                                0.001
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.141767
# Rec.                                                  -4.63443
# F-1                                                    0.03059
# #deps                                                       32
# Name: 2, dtype: object
# [GenerativeModel] Model <GenerativeModel_1> loaded.
# Model                                                        9
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.141767
# Rec.                                                  -4.63443
# F-1                                                    0.03059
# #deps                                                       32
# Name: 10, dtype: object
# [GenerativeModel] Model <GenerativeModel_9> loaded.
# Model                                                       19
# epochs                                                     300
# step_size                                                0.001
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.143175
# Rec.                                                  -4.70102
# F-1                                                  0.0304562
# #deps                                                       30
# Name: 17, dtype: object
# [GenerativeModel] Model <GenerativeModel_19> loaded.
# Model                                                       64
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.145212
# Rec.                                                  -4.88491
# F-1                                                  0.0297267
# #deps                                                       30
# Name: 63, dtype: object
# [GenerativeModel] Model <GenerativeModel_64> loaded.
# Model                                                       37
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.142448
# Rec.                                                  -4.79349
# F-1                                                   0.029717
# #deps                                                       32
# Name: 36, dtype: object
# [GenerativeModel] Model <GenerativeModel_37> loaded.
# Model                                                       74
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.142448
# Rec.                                                  -4.79349
# F-1                                                   0.029717
# #deps                                                       32
# Name: 74, dtype: object
# [GenerativeModel] Model <GenerativeModel_74> loaded.
# Model                                                       23
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.142448
# Rec.                                                  -4.79349
# F-1                                                   0.029717
# #deps                                                       32
# Name: 24, dtype: object
# [GenerativeModel] Model <GenerativeModel_23> loaded.
# Model                                                        4
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.95
# Prec.                                                 0.142448
# Rec.                                                  -4.79349
# F-1                                                   0.029717
# #deps                                                       32
# Name: 1, dtype: object
# [GenerativeModel] Model <GenerativeModel_4> loaded.
# Model                                                       18
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-100
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.146249
# Rec.                                                  -5.03382
# F-1                                                  0.0290532
# #deps                                                       32
# Name: 18, dtype: object
# [GenerativeModel] Model <GenerativeModel_18> loaded.
# Model                                                       30
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.146249
# Rec.                                                  -5.03382
# F-1                                                  0.0290532
# #deps                                                       32
# Name: 29, dtype: object
# [GenerativeModel] Model <GenerativeModel_30> loaded.
# Model                                                       77
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.146249
# Rec.                                                  -5.03382
# F-1                                                  0.0290532
# #deps                                                       32
# Name: 76, dtype: object
# [GenerativeModel] Model <GenerativeModel_77> loaded.
# Model                                                       16
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.146249
# Rec.                                                  -5.03382
# F-1                                                  0.0290532
# #deps                                                       32
# Name: 16, dtype: object
# [GenerativeModel] Model <GenerativeModel_16> loaded.
# Model                                                       46
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                               1e-200
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.143583
# Rec.                                                  -5.05275
# F-1                                                  0.0284168
# #deps                                                       34
# Name: 45, dtype: object
# [GenerativeModel] Model <GenerativeModel_46> loaded.
# Model                                                       49
# epochs                                                     300
# step_size                                                 0.01
# reg_param                                                1e-50
# deps         {(4, 7, 0), (6, 9, 0), (1, 10, 0), (3, 9, 0), ...
# decay                                                     0.99
# Prec.                                                 0.143583
# Rec.                                                  -5.05275
# F-1                                                  0.0284168
# #deps                                                       34
# Name: 49, dtype: object
# [GenerativeModel] Model <GenerativeModel_49> loaded.

# %%
# pick model 8

# %%
gen_model.load('GenerativeModel_8', save_dir='checkpoints/grid_search/')
unlab_marginals_us = gen_model.marginals(L_train_us)
# Out:
# [GenerativeModel] Model <GenerativeModel_8> loaded.

# %%
plt.hist(train_marginals_us, bins=20)
plt.title('Histogram of marginals with candidates undersampled before GM ')
plt.show()

# %%
_ = gen_model.error_analysis(session, L_dev, L_gold_dev)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.645
# Neg. class accuracy: 0.795
# Precision            0.468
# Recall               0.645
# F1                   0.542
# ----------------------------------------
# TP: 455 | FP: 518 | TN: 2007 | FN: 250
# ========================================

# %%
L_train_us
# Out:
# <10208x12 sparse matrix of type '<type 'numpy.int64'>'
# 	with 122496 stored elements in Compressed Sparse Row format>

# %%
save_marginals(session, L_train, train_marginals_us)
# Out:
# Saved 10208 marginals

# %% [markdown]
# # Discriminative model learning

# %%
from snorkel.learning import reRNN

# %%
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)
L_gold_test
# Out:
# <8335x1 sparse matrix of type '<type 'numpy.int64'>'
# 	with 8335 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ** Without GS **

# %%
plt.hist(train_marginals_us, bins=20)
plt.title('Histogram of marginals with candidates undersampled before GM ')
plt.show()

# %%
train_kwargs = {
    'lr':         0.01,
    'dim':        100,
    'n_epochs':   20,
    'dropout':    0.5,
    'rebalance':  True,
    'print_freq': 1,
    'batch_size': 64
}

lstm = reRNN(seed=1701, n_threads=6,)
lstm.train(unlab_us, unlab_marginals_us , X_dev=dev, Y_dev=L_gold_dev, **train_kwargs)
# Out:
# /home/antonis/anaconda2/envs/snorkel27clone/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# [reRNN] Training model
# [reRNN] n_train=9552  #epochs=20  batch size=64
# [reRNN] Epoch 0 (52.83s)	Average loss=0.694253	Dev F1=31.66
# [reRNN] Epoch 1 (110.47s)	Average loss=0.687902	Dev F1=32.00
# [reRNN] Epoch 2 (166.26s)	Average loss=0.646877	Dev F1=33.53
# [reRNN] Epoch 3 (224.80s)	Average loss=0.603902	Dev F1=28.32
# [reRNN] Epoch 4 (282.38s)	Average loss=0.579879	Dev F1=31.20
# [reRNN] Epoch 5 (339.29s)	Average loss=0.559674	Dev F1=30.68
# [reRNN] Epoch 6 (397.28s)	Average loss=0.550173	Dev F1=31.55
# [reRNN] Epoch 7 (454.93s)	Average loss=0.540777	Dev F1=31.65
# [reRNN] Epoch 8 (511.07s)	Average loss=0.535132	Dev F1=32.26
# [reRNN] Epoch 9 (567.37s)	Average loss=0.530006	Dev F1=30.92
# [reRNN] Epoch 10 (624.83s)	Average loss=0.526469	Dev F1=31.58
# [reRNN] Epoch 11 (682.48s)	Average loss=0.524086	Dev F1=32.09
# [reRNN] Epoch 12 (740.15s)	Average loss=0.523114	Dev F1=32.10
# [reRNN] Epoch 13 (797.64s)	Average loss=0.520714	Dev F1=29.48
# [reRNN] Epoch 14 (857.29s)	Average loss=0.520527	Dev F1=31.23
# [reRNN] Epoch 15 (913.01s)	Average loss=0.519752	Dev F1=29.73
# [reRNN] Epoch 16 (969.37s)	Average loss=0.519411	Dev F1=30.10
# [reRNN] Model saved as <reRNN>
# [reRNN] Epoch 17 (1025.05s)	Average loss=0.519815	Dev F1=30.40
# [reRNN] Model saved as <reRNN>
# [reRNN] Epoch 18 (1080.64s)	Average loss=0.518471	Dev F1=32.16
# [reRNN] Model saved as <reRNN>
# [reRNN] Epoch 19 (1136.07s)	Average loss=0.515491	Dev F1=31.61
# [reRNN] Training done (1141.02s)
# INFO:tensorflow:Restoring parameters from checkpoints/reRNN/reRNN-18
# [reRNN] Loaded model <reRNN>

# %%
tp, fp, tn, fn = lstm.error_analysis(session, dev, L_gold_dev)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.555
# Neg. class accuracy: 0.476
# Precision            0.228
# Recall               0.555
# F1                   0.323
# ----------------------------------------
# TP: 391 | FP: 1323 | TN: 1202 | FN: 314
# ========================================

# %%
tp, fp, tn, fn = lstm.error_analysis(session, test, L_gold_test)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.513
# Neg. class accuracy: 0.49
# Precision            0.24
# Recall               0.513
# F1                   0.327
# ----------------------------------------
# TP: 1020 | FP: 3235 | TN: 3113 | FN: 967
# ========================================

# %% [markdown]
# ** With GS **

# %%
from snorkel.annotations import load_marginals
train_labels = np.array([0 if train[x].gold_labels[0].value ==-1 else 1 for x in range(len(train))]) # load train labels to mix in LSTM
unlab_marginals = load_marginals(session, split=3)

# %%
train_us, train_labels_us = balance_candidates(train,train_labels)

# %%
train_unlab_marginals = np.append(train_labels_us, unlab_marginals_us)

# %%
plt.hist(train_unlab_marginals, bins=20)
plt.title('Histogram of marginals (candidates undersampled before GM) + GS ')
plt.show()

# %%
train_kwargs = {
    'lr':         0.01,
    'dim':        100,
    'n_epochs':   25,
    'dropout':    0.5,
    'rebalance':  False,
    'print_freq': 1,
    'batch_size': 64
}

lstm = reRNN(seed=1701, n_threads=6)
lstm.train(train_us+unlab_us, train_unlab_marginals, X_dev=dev, Y_dev=L_gold_dev, **train_kwargs)
# Out:
# /home/antonis/anaconda2/envs/snorkel27clone/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# [reRNN] Training model
# [reRNN] n_train=16812  #epochs=25  batch size=64
# [reRNN] Epoch 0 (88.69s)	Average loss=0.670389	Dev F1=39.58
# [reRNN] Epoch 1 (184.20s)	Average loss=0.574475	Dev F1=38.89
# [reRNN] Epoch 2 (275.40s)	Average loss=0.505027	Dev F1=39.16
# [reRNN] Epoch 3 (366.70s)	Average loss=0.466436	Dev F1=37.59
# [reRNN] Epoch 4 (454.71s)	Average loss=0.441739	Dev F1=38.47
# [reRNN] Epoch 5 (542.95s)	Average loss=0.426697	Dev F1=38.74
# [reRNN] Epoch 6 (634.96s)	Average loss=0.411845	Dev F1=39.47
# [reRNN] Epoch 7 (728.01s)	Average loss=0.409247	Dev F1=38.63
# [reRNN] Epoch 8 (819.16s)	Average loss=0.399574	Dev F1=37.49
# [reRNN] Epoch 9 (908.25s)	Average loss=0.390756	Dev F1=37.85
# [reRNN] Epoch 10 (997.79s)	Average loss=0.384978	Dev F1=38.67
# [reRNN] Epoch 11 (1092.79s)	Average loss=0.378557	Dev F1=39.58
# [reRNN] Epoch 12 (1187.15s)	Average loss=0.373485	Dev F1=39.83
# [reRNN] Epoch 13 (1281.62s)	Average loss=0.368622	Dev F1=39.33
# [reRNN] Epoch 14 (1375.18s)	Average loss=0.367330	Dev F1=38.88
# [reRNN] Epoch 15 (1467.51s)	Average loss=0.367530	Dev F1=39.51
# [reRNN] Epoch 16 (1560.21s)	Average loss=0.368580	Dev F1=38.59
# [reRNN] Epoch 17 (1652.80s)	Average loss=0.369854	Dev F1=36.91
# [reRNN] Epoch 18 (1742.40s)	Average loss=0.362258	Dev F1=37.33
# [reRNN] Epoch 19 (1833.73s)	Average loss=0.363436	Dev F1=37.80
# [reRNN] Model saved as <reRNN>
# [reRNN] Epoch 20 (1928.64s)	Average loss=0.362737	Dev F1=36.07
# [reRNN] Epoch 21 (2023.49s)	Average loss=0.357714	Dev F1=39.24
# [reRNN] Model saved as <reRNN>
# [reRNN] Epoch 22 (2114.23s)	Average loss=0.357332	Dev F1=37.42
# [reRNN] Epoch 23 (2209.35s)	Average loss=0.355261	Dev F1=37.91
# [reRNN] Epoch 24 (2304.09s)	Average loss=0.351221	Dev F1=39.07
# [reRNN] Training done (2309.33s)
# INFO:tensorflow:Restoring parameters from checkpoints/reRNN/reRNN-21
# [reRNN] Loaded model <reRNN>

# %%
tp, fp, tn, fn = lstm.error_analysis(session, dev, L_gold_dev)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.618
# Neg. class accuracy: 0.578
# Precision            0.29
# Recall               0.618
# F1                   0.395
# ----------------------------------------
# TP: 436 | FP: 1066 | TN: 1459 | FN: 269
# ========================================

# %%
tp, fp, tn, fn = lstm.error_analysis(session, test, L_gold_test)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.639
# Neg. class accuracy: 0.542
# Precision            0.304
# Recall               0.639
# F1                   0.412
# ----------------------------------------
# TP: 1269 | FP: 2909 | TN: 3439 | FN: 718
# ========================================

# %% [markdown]
# # ~~~~

# %% [markdown]
# # Try with linear weighting

# %% [markdown]
# ** Majority Voting **

# %%
linear_gen_model = GenerativeModelLinear()

# %%
marginals_maj_vote = linear_gen_model.marginals(L_train, majority_voting=True)

# %%
plt.hist(marginals_maj_vote, bins=20)
plt.title('Histogram of majority votes (created with %i models)'%L_train.shape[1])
plt.show()

# %%
save_marginals(session, L_train, marginals_maj_vote)
# Out:
# Saved 79400 marginals

# %%
from snorkel.learning import  GenerativeModel, RandomSearch

# %% [markdown]
# ** No weighting **

# %%
marginals_linear_comb = linear_gen_model.marginals(L_train, lf_weights=1)

# %%
plt.hist(marginals_linear_comb, bins=20)
plt.title('Histogram of probabilistic labels (unweighted average / %i models)'%L_train.shape[1])
plt.show()

# %%
save_marginals(session, L_train, marginals_linear_comb)
# Out:
# Saved 79400 marginals

# %% [markdown]
# ** Weighting proportional to F1 score **

# %%
results_dict.keys()
# Out:
# ['results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear',
#  'results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear',
#  'RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,max_sent_length=64_biLSTM',
#  'fasttext_fasttext',
#  'results_dict,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(0, 3),LSA100_NeuralNet(10,10)',
#  'results_dict,lemmas,RuS,CV_,bin_,minFreq=1,_ngrams=(1, 1),LSA100_LogisticRegression',
#  'results_dict,trim=5,lemmas,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(1, 1),LSA100_RandomForestClassifier',
#  'results_dict,trim=5,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(0, 3),LSA100_SVC_linear',
#  'results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngrams=(1, 1),LSA100_RandomForestClassifier',
#  'results_dict,trim=5,lemmas,RuS,CV_,bin_,minFreq=1,_stopw=english,_ngrams=(1, 1),LSA100_LogisticRegression',
#  'results_dict,ShortDepPath,RuS,TfIdf_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear',
#  'results_dict,lemmas,RuS,TfIdf_,minFreq=1,_stopw=english,_ngrams=(1, 1),LSA100_RandomForestClassifier']

# %%
lf_weights= []
for model_name in results_dict.keys():
    lf_weights.append(results_dict[model_name]['f1+'])
lf_weights = np.array(lf_weights)

# %%
linear_gen_model = GenerativeModelLinear()

# %%
marginals_linear_comb = linear_gen_model.marginals(L_train, lf_weights=lf_weights)

# %%
marginals_linear_comb
# Out:
# array([ 0.26232784,  0.26232784,  0.44517216, ...,  0.26566118,
#         0.50399451,  0.49267216])

# %%
plt.hist(marginals_linear_comb, bins=20)
plt.title('Histogram of probabilistic labels (F1+ weighted average / %i models)'%L_train.shape[1])
plt.show()

# %%
save_marginals(session, L_train, marginals_linear_comb)
# Out:
# Saved 79400 marginals

# %%
# lf_weights = np.array([2, 0, 3, 3, 3, 0, 0, 0, 0, 0, 0, 0])

# #if not given lf_weights = np.ones(L_train.shape[1])

# L_weighted = L_train.multiply(lf_weights)/lf_weights.sum()

# %%
item = L_train.mean(axis=1)[0]

# %%
item
# Out:
# matrix([[-0.83333333]])

# %% [markdown]
# # GM training (normal - snorkels way)

# %%
# %%time
# ### Normal training

# # actual training of the gen. model
# from snorkel.learning import GenerativeModel

# gen_model = GenerativeModel(lf_propensity=False, class_prior=True )
# gen_model.train(
#     L_train, decay=0.95, step_size=0.1/L_train.shape[0], reg_param=1e-6,  threads = 6,
#     deps=deps,
# )

# train_marginals = gen_model.marginals(L_train)
# Out:
# Inferred cardinality: 2
# CPU times: user 2min 17s, sys: 141 ms, total: 2min 18s
# Wall time: 1min 30s

# %%
# Out:
# 4

# %%
plt.hist(train_marginals, bins=20)
plt.title('Histogram of probabilistic labels (created with %i models)'%L_train.shape[1])
plt.show()

# %%
n_models = len(results_dict.keys())

# %%
from MLutils import diversity_matrix

# %%
diversity_matrix(results_dict,metric=accuracy_score).mean().mean()
# Out:
# 0.80003869969040242

# %%
diversity_matrix(results_dict,metric=cohen_kappa_score).mean().mean()
# Out:
# 0.5113189606834152

# %%
plt.hist(train_marginals, bins=20)
plt.title('Histogram of probabilistic labels (created with %i models & LF_prior=True, LF_propensity=False)'%n_models)
plt.show()

# %%
len(train_marginalsinals)
# Out:
# 79400

# %%
print 'Inferred performance metrics by snorkel:'
gen_model.learned_lf_stats()
# Out:
# Inferred performance metrics by snorkel:
#    Accuracy  Coverage  Precision    Recall
# 0  0.971729    0.8737   0.797044  0.820487
# 1  0.937507    0.8369   0.629160  0.805274
# 2  0.925276    0.8324   0.575373  0.781947
# 3  0.895110    0.8037   0.492881  0.737323

# %% [markdown]
# ## Check performance on developer set

# %%
# TODO: to do that, we need to also take labels from a different dictionary

# %%
gen_model.learned_lf_stats()
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.968743    0.8734   0.800826  0.850746
# 1  0.941741    0.8342   0.671815  0.763828
# 2  0.926562    0.8211   0.618130  0.760316
# 3  0.897070    0.8054   0.529931  0.738367

# %%
gen_model.weights.lf_accuracy
# Out:
# array([ 1.32927991,  0.96930229,  0.89196357,  0.71774052])

# %%
gen_model.score(L_dev,L_gold_dev)
# Out:
# (0.67838312829525482, 0.54751773049645391, 0.60596546310832033)

# %%
np.exp(-8*((.81+.79+.75+.73)/4)**2)
# Out:
# 0.0087107272118617431

# %%
L_dev.lf_stats(session, L_gold_dev,)
# Out:
#                                                     j  Coverage  Overlaps  \
# fasttext_fasttext                                   0       1.0       1.0
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...  1       1.0       1.0
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...  2       1.0       1.0
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...  3       1.0       1.0
#
#                                                     Conflicts   TP   FP   FN  \
# fasttext_fasttext                                    0.486687  324  225  381
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...   0.486687  508  459  197
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...   0.486687  446  519  259
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...   0.486687  520  658  185
#
#                                                       TN  Empirical Acc.
# fasttext_fasttext                                   2300        0.812384
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...  2066        0.796904
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...  2006        0.759133
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...  1867        0.739009

# %%
learned_stats = L_dev.lf_stats(session, L_gold_dev, gen_model.learned_lf_stats()['Accuracy'])
learned_stats
# Out:
#                                                     j  Coverage  Overlaps  \
# fasttext_fasttext                                   0       1.0       1.0
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...  1       1.0       1.0
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...  2       1.0       1.0
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...  3       1.0       1.0
#
#                                                     Conflicts   TP   FP   FN  \
# fasttext_fasttext                                    0.486687  324  225  381
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...   0.486687  508  459  197
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...   0.486687  446  519  259
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...   0.486687  520  658  185
#
#                                                       TN  Empirical Acc.  \
# fasttext_fasttext                                   2300        0.812384
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...  2066        0.796904
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...  2006        0.759133
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...  1867        0.739009
#
#                                                     Learned Acc.
# fasttext_fasttext                                       0.968112
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...      0.935136
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...      0.924378
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...      0.896389

# %% [markdown]
# ### Try with priors = F1 score

# %%
gen_model_prior = GenerativeModel()

# %%
gen_model_prior.train(L_train, LF_acc_prior_weights=[0.5167, 0.60765, 0.5341, 0.5523 ])
# Out:
# Inferred cardinality: 2

# %%
# to pass priors as F1 score
from sklearn.metrics import f1_score

for row in learned_stats.iterrows():
    print row[0]
    tp = row[1]['TP']
    tn = row[1]['TN']
    fp = row[1]['FP']
    fn = row[1]['FN']
    pr = float(tp)/(tp+fp)
    rec = float(tp)/(tp+fn)
    f1 = (2*pr*rec)/(pr+rec)
    print f1
# Out:
# fasttext_fasttext
# 0.516746411483
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=1,_ngrams=(0, 3),LSA100_SVC_linear
# 0.607655502392
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,max_sent_length=64_biLSTM
# 0.534131736527
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngrams=(1, 1),LSA100_RandomForestClassifier
# 0.552310143388

# %%
# # export to latex
# print learned_stats.drop(labels=['j','Coverage', 'Overlaps', 'Conflicts'], axis=1).reset_index(drop=True).to_latex()

# %% [markdown]
# ### Put it in a log

# %%
gen_model_prior_log = GenerativeModel()

# %%
# TODO: try this from  snorkel/test/learning/test_supervised.py


LF_acc_priors = [0.5167, 0.60765, 0.5341, 0.5523 ]
cardinality = 2
LF_acc_prior_weights = [0.5 * np.log((cardinality - 1.0) * x / (1 - x)) for x in LF_acc_priors]

# %%
LF_acc_prior_weights
# Out:
# [0.033412428221050325,
#  0.2187223798716636,
#  0.068306034261486848,
#  0.10498400583011107]

# %%
gen_model_prior_log.train(L_train, LF_acc_prior_weights=LF_acc_prior_weights)
# Out:
# Inferred cardinality: 2

# %% [markdown]
# ### Compare results

# %%
gen_model_prior_log.learned_lf_stats()
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.936173    0.8006   0.938447  0.750098
# 1  0.901056    0.7671   0.906266  0.700312
# 2  0.871032    0.7498   0.874868  0.648380
# 3  0.837408    0.7362   0.844474  0.619094

# %%
gen_model_prior.learned_lf_stats()
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.953406    0.8220   0.956984  0.789125
# 1  0.909594    0.7776   0.912752  0.715650
# 2  0.895702    0.7632   0.899871  0.681349
# 3  0.853391    0.7462   0.861635  0.640811

# %%
gen_model.learned_lf_stats() # before passing LF_acc_prior_weights
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.971318    0.8751   0.760460  0.838524
# 1  0.940309    0.8410   0.599103  0.770473
# 2  0.929846    0.8239   0.554054  0.756632
# 3  0.896266    0.8088   0.449892  0.719723

# %%
gen_model.learned_lf_stats()
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.943857    0.8033   0.150659  0.776699
# 1  0.913150    0.7749   0.099050  0.708738
# 2  0.928156    0.7906   0.118565  0.737864
# 3  0.917995    0.7841   0.103546  0.708738

# %%
L_train
# Out:
# (79400, 4)

# %%
L_train.row_index
# Out:
# {0: 40197,
#  1: 40198,
#  2: 40199,
#  3: 40200,
#  4: 40201,
#  5: 40202,
#  6: 40203,
#  7: 40204,
#  8: 40205,
#  9: 40206,
#  10: 40207,
#  11: 40208,
#  12: 40209,
#  13: 40210,
#  14: 40211,
#  15: 40212,
#  16: 40213,
#  17: 40214,
#  18: 40215,
#  19: 40216,
#  20: 40217,
#  21: 40218,
#  22: 40219,
#  23: 40220,
#  24: 40221,
#  25: 40222,
#  26: 40223,
#  27: 40224,
#  28: 40225,
#  29: 40226,
#  30: 40227,
#  31: 40228,
#  32: 40229,
#  33: 40230,
#  34: 40231,
#  35: 40232,
#  36: 40233,
#  37: 40234,
#  38: 40235,
#  39: 40236,
#  40: 40237,
#  41: 40238,
#  42: 40239,
#  43: 40240,
#  44: 40241,
#  45: 40242,
#  46: 40243,
#  47: 40244,
#  48: 40245,
#  49: 40246,
#  50: 40247,
#  51: 40248,
#  52: 40249,
#  53: 40250,
#  54: 40251,
#  55: 40252,
#  56: 40253,
#  57: 40254,
#  58: 40255,
#  59: 40256,
#  60: 40257,
#  61: 40258,
#  62: 40259,
#  63: 40260,
#  64: 40261,
#  65: 40262,
#  66: 40263,
#  67: 40264,
#  68: 40265,
#  69: 40266,
#  70: 40267,
#  71: 40268,
#  72: 40269,
#  73: 40270,
#  74: 40271,
#  75: 40272,
#  76: 40273,
#  77: 40274,
#  78: 40275,
#  79: 40276,
#  80: 40277,
#  81: 40278,
#  82: 40279,
#  83: 40280,
#  84: 40281,
#  85: 40282,
#  86: 40283,
#  87: 40284,
#  88: 40285,
#  89: 40286,
#  90: 40287,
#  91: 40288,
#  92: 40289,
#  93: 40290,
#  94: 40291,
#  95: 40292,
#  96: 40293,
#  97: 40294,
#  98: 40295,
#  99: 40296,
#  100: 40297,
#  101: 40298,
#  102: 40299,
#  103: 40300,
#  104: 40301,
#  105: 40302,
#  106: 40303,
#  107: 40304,
#  108: 40305,
#  109: 40306,
#  110: 40307,
#  111: 40308,
#  112: 40309,
#  113: 40310,
#  114: 40311,
#  115: 40312,
#  116: 40313,
#  117: 40314,
#  118: 40315,
#  119: 40316,
#  120: 40317,
#  121: 40318,
#  122: 40319,
#  123: 40320,
#  124: 40321,
#  125: 40322,
#  126: 40323,
#  127: 40324,
#  128: 40325,
#  129: 40326,
#  130: 40327,
#  131: 40328,
#  132: 40329,
#  133: 40330,
#  134: 40331,
#  135: 40332,
#  136: 40333,
#  137: 40334,
#  138: 40335,
#  139: 40336,
#  140: 40337,
#  141: 40338,
#  142: 40339,
#  143: 40340,
#  144: 40341,
#  145: 40342,
#  146: 40343,
#  147: 40344,
#  148: 40345,
#  149: 40346,
#  150: 40347,
#  151: 40348,
#  152: 40349,
#  153: 40350,
#  154: 40351,
#  155: 40352,
#  156: 40353,
#  157: 40354,
#  158: 40355,
#  159: 40356,
#  160: 40357,
#  161: 40358,
#  162: 40359,
#  163: 40360,
#  164: 40361,
#  165: 40362,
#  166: 40363,
#  167: 40364,
#  168: 40365,
#  169: 40366,
#  170: 40367,
#  171: 40368,
#  172: 40369,
#  173: 40370,
#  174: 40371,
#  175: 40372,
#  176: 40373,
#  177: 40374,
#  178: 40375,
#  179: 40376,
#  180: 40377,
#  181: 40378,
#  182: 40379,
#  183: 40380,
#  184: 40381,
#  185: 40382,
#  186: 40383,
#  187: 40384,
#  188: 40385,
#  189: 40386,
#  190: 40387,
#  191: 40388,
#  192: 40389,
#  193: 40390,
#  194: 40391,
#  195: 40392,
#  196: 40393,
#  197: 40394,
#  198: 40395,
#  199: 40396,
#  200: 40397,
#  201: 40398,
#  202: 40399,
#  203: 40400,
#  204: 40401,
#  205: 40402,
#  206: 40403,
#  207: 40404,
#  208: 40405,
#  209: 40406,
#  210: 40407,
#  211: 40408,
#  212: 40409,
#  213: 40410,
#  214: 40411,
#  215: 40412,
#  216: 40413,
#  217: 40414,
#  218: 40415,
#  219: 40416,
#  220: 40417,
#  221: 40418,
#  222: 40419,
#  223: 40420,
#  224: 40421,
#  225: 40422,
#  226: 40423,
#  227: 40424,
#  228: 40425,
#  229: 40426,
#  230: 40427,
#  231: 40428,
#  232: 40429,
#  233: 40430,
#  234: 40431,
#  235: 40432,
#  236: 40433,
#  237: 40434,
#  238: 40435,
#  239: 40436,
#  240: 40437,
#  241: 40438,
#  242: 40439,
#  243: 40440,
#  244: 40441,
#  245: 40442,
#  246: 40443,
#  247: 40444,
#  248: 40445,
#  249: 40446,
#  250: 40447,
#  251: 40448,
#  252: 40449,
#  253: 40450,
#  254: 40451,
#  255: 40452,
#  256: 40453,
#  257: 40454,
#  258: 40455,
#  259: 40456,
#  260: 40457,
#  261: 40458,
#  262: 40459,
#  263: 40460,
#  264: 40461,
#  265: 40462,
#  266: 40463,
#  267: 40464,
#  268: 40465,
#  269: 40466,
#  270: 40467,
#  271: 40468,
#  272: 40469,
#  273: 40470,
#  274: 40471,
#  275: 40472,
#  276: 40473,
#  277: 40474,
#  278: 40475,
#  279: 40476,
#  280: 40477,
#  281: 40478,
#  282: 40479,
#  283: 40480,
#  284: 40481,
#  285: 40482,
#  286: 40483,
#  287: 40484,
#  288: 40485,
#  289: 40486,
#  290: 40487,
#  291: 40488,
#  292: 40489,
#  293: 40490,
#  294: 40491,
#  295: 40492,
#  296: 40493,
#  297: 40494,
#  298: 40495,
#  299: 40496,
#  300: 40497,
#  301: 40498,
#  302: 40499,
#  303: 40500,
#  304: 40501,
#  305: 40502,
#  306: 40503,
#  307: 40504,
#  308: 40505,
#  309: 40506,
#  310: 40507,
#  311: 40508,
#  312: 40509,
#  313: 40510,
#  314: 40511,
#  315: 40512,
#  316: 40513,
#  317: 40514,
#  318: 40515,
#  319: 40516,
#  320: 40517,
#  321: 40518,
#  322: 40519,
#  323: 40520,
#  324: 40521,
#  325: 40522,
#  326: 40523,
#  327: 40524,
#  328: 40525,
#  329: 40526,
#  330: 40527,
#  331: 40528,
#  332: 40529,
#  333: 40530,
#  334: 40531,
#  335: 40532,
#  336: 40533,
#  337: 40534,
#  338: 40535,
#  339: 40536,
#  340: 40537,
#  341: 40538,
#  342: 40539,
#  343: 40540,
#  344: 40541,
#  345: 40542,
#  346: 40543,
#  347: 40544,
#  348: 40545,
#  349: 40546,
#  350: 40547,
#  351: 40548,
#  352: 40549,
#  353: 40550,
#  354: 40551,
#  355: 40552,
#  356: 40553,
#  357: 40554,
#  358: 40555,
#  359: 40556,
#  360: 40557,
#  361: 40558,
#  362: 40559,
#  363: 40560,
#  364: 40561,
#  365: 40562,
#  366: 40563,
#  367: 40564,
#  368: 40565,
#  369: 40566,
#  370: 40567,
#  371: 40568,
#  372: 40569,
#  373: 40570,
#  374: 40571,
#  375: 40572,
#  376: 40573,
#  377: 40574,
#  378: 40575,
#  379: 40576,
#  380: 40577,
#  381: 40578,
#  382: 40579,
#  383: 40580,
#  384: 40581,
#  385: 40582,
#  386: 40583,
#  387: 40584,
#  388: 40585,
#  389: 40586,
#  390: 40587,
#  391: 40588,
#  392: 40589,
#  393: 40590,
#  394: 40591,
#  395: 40592,
#  396: 40593,
#  397: 40594,
#  398: 40595,
#  399: 40596,
#  400: 40597,
#  401: 40598,
#  402: 40599,
#  403: 40600,
#  404: 40601,
#  405: 40602,
#  406: 40603,
#  407: 40604,
#  408: 40605,
#  409: 40606,
#  410: 40607,
#  411: 40608,
#  412: 40609,
#  413: 40610,
#  414: 40611,
#  415: 40612,
#  416: 40613,
#  417: 40614,
#  418: 40615,
#  419: 40616,
#  420: 40617,
#  421: 40618,
#  422: 40619,
#  423: 40620,
#  424: 40621,
#  425: 40622,
#  426: 40623,
#  427: 40624,
#  428: 40625,
#  429: 40626,
#  430: 40627,
#  431: 40628,
#  432: 40629,
#  433: 40630,
#  434: 40631,
#  435: 40632,
#  436: 40633,
#  437: 40634,
#  438: 40635,
#  439: 40636,
#  440: 40637,
#  441: 40638,
#  442: 40639,
#  443: 40640,
#  444: 40641,
#  445: 40642,
#  446: 40643,
#  447: 40644,
#  448: 40645,
#  449: 40646,
#  450: 40647,
#  451: 40648,
#  452: 40649,
#  453: 40650,
#  454: 40651,
#  455: 40652,
#  456: 40653,
#  457: 40654,
#  458: 40655,
#  459: 40656,
#  460: 40657,
#  461: 40658,
#  462: 40659,
#  463: 40660,
#  464: 40661,
#  465: 40662,
#  466: 40663,
#  467: 40664,
#  468: 40665,
#  469: 40666,
#  470: 40667,
#  471: 40668,
#  472: 40669,
#  473: 40670,
#  474: 40671,
#  475: 40672,
#  476: 40673,
#  477: 40674,
#  478: 40675,
#  479: 40676,
#  480: 40677,
#  481: 40678,
#  482: 40679,
#  483: 40680,
#  484: 40681,
#  485: 40682,
#  486: 40683,
#  487: 40684,
#  488: 40685,
#  489: 40686,
#  490: 40687,
#  491: 40688,
#  492: 40689,
#  493: 40690,
#  494: 40691,
#  495: 40692,
#  496: 40693,
#  497: 40694,
#  498: 40695,
#  499: 40696,
#  500: 40697,
#  501: 40698,
#  502: 40699,
#  503: 40700,
#  504: 40701,
#  505: 40702,
#  506: 40703,
#  507: 40704,
#  508: 40705,
#  509: 40706,
#  510: 40707,
#  511: 40708,
#  512: 40709,
#  513: 40710,
#  514: 40711,
#  515: 40712,
#  516: 40713,
#  517: 40714,
#  518: 40715,
#  519: 40716,
#  520: 40717,
#  521: 40718,
#  522: 40719,
#  523: 40720,
#  524: 40721,
#  525: 40722,
#  526: 40723,
#  527: 40724,
#  528: 40725,
#  529: 40726,
#  530: 40727,
#  531: 40728,
#  532: 40729,
#  533: 40730,
#  534: 40731,
#  535: 40732,
#  536: 40733,
#  537: 40734,
#  538: 40735,
#  539: 40736,
#  540: 40737,
#  541: 40738,
#  542: 40739,
#  543: 40740,
#  544: 40741,
#  545: 40742,
#  546: 40743,
#  547: 40744,
#  548: 40745,
#  549: 40746,
#  550: 40747,
#  551: 40748,
#  552: 40749,
#  553: 40750,
#  554: 40751,
#  555: 40752,
#  556: 40753,
#  557: 40754,
#  558: 40755,
#  559: 40756,
#  560: 40757,
#  561: 40758,
#  562: 40759,
#  563: 40760,
#  564: 40761,
#  565: 40762,
#  566: 40763,
#  567: 40764,
#  568: 40765,
#  569: 40766,
#  570: 40767,
#  571: 40768,
#  572: 40769,
#  573: 40770,
#  574: 40771,
#  575: 40772,
#  576: 40773,
#  577: 40774,
#  578: 40775,
#  579: 40776,
#  580: 40777,
#  581: 40778,
#  582: 40779,
#  583: 40780,
#  584: 40781,
#  585: 40782,
#  586: 40783,
#  587: 40784,
#  588: 40785,
#  589: 40786,
#  590: 40787,
#  591: 40788,
#  592: 40789,
#  593: 40790,
#  594: 40791,
#  595: 40792,
#  596: 40793,
#  597: 40794,
#  598: 40795,
#  599: 40796,
#  600: 40797,
#  601: 40798,
#  602: 40799,
#  603: 40800,
#  604: 40801,
#  605: 40802,
#  606: 40803,
#  607: 40804,
#  608: 40805,
#  609: 40806,
#  610: 40807,
#  611: 40808,
#  612: 40809,
#  613: 40810,
#  614: 40811,
#  615: 40812,
#  616: 40813,
#  617: 40814,
#  618: 40815,
#  619: 40816,
#  620: 40817,
#  621: 40818,
#  622: 40819,
#  623: 40820,
#  624: 40821,
#  625: 40822,
#  626: 40823,
#  627: 40824,
#  628: 40825,
#  629: 40826,
#  630: 40827,
#  631: 40828,
#  632: 40829,
#  633: 40830,
#  634: 40831,
#  635: 40832,
#  636: 40833,
#  637: 40834,
#  638: 40835,
#  639: 40836,
#  640: 40837,
#  641: 40838,
#  642: 40839,
#  643: 40840,
#  644: 40841,
#  645: 40842,
#  646: 40843,
#  647: 40844,
#  648: 40845,
#  649: 40846,
#  650: 40847,
#  651: 40848,
#  652: 40849,
#  653: 40850,
#  654: 40851,
#  655: 40852,
#  656: 40853,
#  657: 40854,
#  658: 40855,
#  659: 40856,
#  660: 40857,
#  661: 40858,
#  662: 40859,
#  663: 40860,
#  664: 40861,
#  665: 40862,
#  666: 40863,
#  667: 40864,
#  668: 40865,
#  669: 40866,
#  670: 40867,
#  671: 40868,
#  672: 40869,
#  673: 40870,
#  674: 40871,
#  675: 40872,
#  676: 40873,
#  677: 40874,
#  678: 40875,
#  679: 40876,
#  680: 40877,
#  681: 40878,
#  682: 40879,
#  683: 40880,
#  684: 40881,
#  685: 40882,
#  686: 40883,
#  687: 40884,
#  688: 40885,
#  689: 40886,
#  690: 40887,
#  691: 40888,
#  692: 40889,
#  693: 40890,
#  694: 40891,
#  695: 40892,
#  696: 40893,
#  697: 40894,
#  698: 40895,
#  699: 40896,
#  700: 40897,
#  701: 40898,
#  702: 40899,
#  703: 40900,
#  704: 40901,
#  705: 40902,
#  706: 40903,
#  707: 40904,
#  708: 40905,
#  709: 40906,
#  710: 40907,
#  711: 40908,
#  712: 40909,
#  713: 40910,
#  714: 40911,
#  715: 40912,
#  716: 40913,
#  717: 40914,
#  718: 40915,
#  719: 40916,
#  720: 40917,
#  721: 40918,
#  722: 40919,
#  723: 40920,
#  724: 40921,
#  725: 40922,
#  726: 40923,
#  727: 40924,
#  728: 40925,
#  729: 40926,
#  730: 40927,
#  731: 40928,
#  732: 40929,
#  733: 40930,
#  734: 40931,
#  735: 40932,
#  736: 40933,
#  737: 40934,
#  738: 40935,
#  739: 40936,
#  740: 40937,
#  741: 40938,
#  742: 40939,
#  743: 40940,
#  744: 40941,
#  745: 40942,
#  746: 40943,
#  747: 40944,
#  748: 40945,
#  749: 40946,
#  750: 40947,
#  751: 40948,
#  752: 40949,
#  753: 40950,
#  754: 40951,
#  755: 40952,
#  756: 40953,
#  757: 40954,
#  758: 40955,
#  759: 40956,
#  760: 40957,
#  761: 40958,
#  762: 40959,
#  763: 40960,
#  764: 40961,
#  765: 40962,
#  766: 40963,
#  767: 40964,
#  768: 40965,
#  769: 40966,
#  770: 40967,
#  771: 40968,
#  772: 40969,
#  773: 40970,
#  774: 40971,
#  775: 40972,
#  776: 40973,
#  777: 40974,
#  778: 40975,
#  779: 40976,
#  780: 40977,
#  781: 40978,
#  782: 40979,
#  783: 40980,
#  784: 40981,
#  785: 40982,
#  786: 40983,
#  787: 40984,
#  788: 40985,
#  789: 40986,
#  790: 40987,
#  791: 40988,
#  792: 40989,
#  793: 40990,
#  794: 40991,
#  795: 40992,
#  796: 40993,
#  797: 40994,
#  798: 40995,
#  799: 40996,
#  800: 40997,
#  801: 40998,
#  802: 40999,
#  803: 41000,
#  804: 41001,
#  805: 41002,
#  806: 41003,
#  807: 41004,
#  808: 41005,
#  809: 41006,
#  810: 41007,
#  811: 41008,
#  812: 41009,
#  813: 41010,
#  814: 41011,
#  815: 41012,
#  816: 41013,
#  817: 41014,
#  818: 41015,
#  819: 41016,
#  820: 41017,
#  821: 41018,
#  822: 41019,
#  823: 41020,
#  824: 41021,
#  825: 41022,
#  826: 41023,
#  827: 41024,
#  828: 41025,
#  829: 41026,
#  830: 41027,
#  831: 41028,
#  832: 41029,
#  833: 41030,
#  834: 41031,
#  835: 41032,
#  836: 41033,
#  837: 41034,
#  838: 41035,
#  839: 41036,
#  840: 41037,
#  841: 41038,
#  842: 41039,
#  843: 41040,
#  844: 41041,
#  845: 41042,
#  846: 41043,
#  847: 41044,
#  848: 41045,
#  849: 41046,
#  850: 41047,
#  851: 41048,
#  852: 41049,
#  853: 41050,
#  854: 41051,
#  855: 41052,
#  856: 41053,
#  857: 41054,
#  858: 41055,
#  859: 41056,
#  860: 41057,
#  861: 41058,
#  862: 41059,
#  863: 41060,
#  864: 41061,
#  865: 41062,
#  866: 41063,
#  867: 41064,
#  868: 41065,
#  869: 41066,
#  870: 41067,
#  871: 41068,
#  872: 41069,
#  873: 41070,
#  874: 41071,
#  875: 41072,
#  876: 41073,
#  877: 41074,
#  878: 41075,
#  879: 41076,
#  880: 41077,
#  881: 41078,
#  882: 41079,
#  883: 41080,
#  884: 41081,
#  885: 41082,
#  886: 41083,
#  887: 41084,
#  888: 41085,
#  889: 41086,
#  890: 41087,
#  891: 41088,
#  892: 41089,
#  893: 41090,
#  894: 41091,
#  895: 41092,
#  896: 41093,
#  897: 41094,
#  898: 41095,
#  899: 41096,
#  900: 41097,
#  901: 41098,
#  902: 41099,
#  903: 41100,
#  904: 41101,
#  905: 41102,
#  906: 41103,
#  907: 41104,
#  908: 41105,
#  909: 41106,
#  910: 41107,
#  911: 41108,
#  912: 41109,
#  913: 41110,
#  914: 41111,
#  915: 41112,
#  916: 41113,
#  917: 41114,
#  918: 41115,
#  919: 41116,
#  920: 41117,
#  921: 41118,
#  922: 41119,
#  923: 41120,
#  924: 41121,
#  925: 41122,
#  926: 41123,
#  927: 41124,
#  928: 41125,
#  929: 41126,
#  930: 41127,
#  931: 41128,
#  932: 41129,
#  933: 41130,
#  934: 41131,
#  935: 41132,
#  936: 41133,
#  937: 41134,
#  938: 41135,
#  939: 41136,
#  940: 41137,
#  941: 41138,
#  942: 41139,
#  943: 41140,
#  944: 41141,
#  945: 41142,
#  946: 41143,
#  947: 41144,
#  948: 41145,
#  949: 41146,
#  950: 41147,
#  951: 41148,
#  952: 41149,
#  953: 41150,
#  954: 41151,
#  955: 41152,
#  956: 41153,
#  957: 41154,
#  958: 41155,
#  959: 41156,
#  960: 41157,
#  961: 41158,
#  962: 41159,
#  963: 41160,
#  964: 41161,
#  965: 41162,
#  966: 41163,
#  967: 41164,
#  968: 41165,
#  969: 41166,
#  970: 41167,
#  971: 41168,
#  972: 41169,
#  973: 41170,
#  974: 41171,
#  975: 41172,
#  976: 41173,
#  977: 41174,
#  978: 41175,
#  979: 41176,
#  980: 41177,
#  981: 41178,
#  982: 41179,
#  983: 41180,
#  984: 41181,
#  985: 41182,
#  986: 41183,
#  987: 41184,
#  988: 41185,
#  989: 41186,
#  990: 41187,
#  991: 41188,
#  992: 41189,
#  993: 41190,
#  994: 41191,
#  995: 41192,
#  996: 41193,
#  997: 41194,
#  998: 41195,
#  999: 41196,
#  ...}

# %% [markdown]
# ### Get and plot marginals

# %%
train_marginals_w_prior = gen_model_prior.marginals(L_train)

# %%
train_marginals_w_prior_log = gen_model_prior_log.marginals(L_train)

# %%
# Plug in directly the F1 score as Lf_accuracy

# %%
plt.hist(train_marginals_w_prior, bins=20)
plt.title('With priors-no logs')
plt.show()

# %%
plt.hist(train_marginals_w_prior_log, bins=20)
plt.title('With priors-with logs')
plt.show()

# %%
L_train
# Out:
# <79400x4 sparse matrix of type '<type 'numpy.int64'>'
# 	with 317600 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Undersample dataset using the generative model

# %%
from MLutils import balance_candidates
from utils import delete_from_csr

# %%
arr = np.fromiter(map(lambda x:x[0].item()>=0.5,L_train.mean(axis=1)), dtype=bool)
lbls = arr*2-1
indices = [i for i in range(L_train.shape[0])]
ind_us, lbls_us = balance_candidates(indices, lbls)
unlab_us = [unlab[i] for i in ind_us]

# %%
ind_to_del = list(set(indices).difference(set(ind_us)))

# %% [markdown]
# # ~

# %%
gen_model.weights.lf_accuracy
# Out:
# array([ 0.5167 ,  0.60765,  0.5341 ,  0.5523 ])

# %%
np.array([0.5167, 0.60765, 0.5341, 0.5523 ])
# Out:
# array([ 0.5167 ,  0.60765,  0.5341 ,  0.5523 ])

# %%
gen_model.weights.lf_accuracy = np.array([0.5167, 0.60765, 0.5341, 0.5523 ])

# %%
train_marginals_F1 = gen_model.marginals(L_train)

# %%
plt.hist(train_marginals_F1, bins=20)
plt.title('Histogram of probabilistic labels (created with %i models & overwritten F1 scores)'%n_models)
plt.show()

# %%
L_dev.lf_stats(session, L_gold_dev, gen_model.learned_lf_stats()['Accuracy'])
# Out:
#                                                     j  Coverage  Overlaps  \
# fasttext_fasttext                                   0       1.0       1.0
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...  1       1.0       1.0
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...  2       1.0       1.0
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...  3       1.0       1.0
#
#                                                     Conflicts   TP   FP   FN  \
# fasttext_fasttext                                    0.486687  324  225  381
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...   0.486687  508  459  197
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...   0.486687  446  519  259
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...   0.486687  520  658  185
#
#                                                       TN  Empirical Acc.  \
# fasttext_fasttext                                   2300        0.812384
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...  2066        0.796904
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...  2006        0.759133
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...  1867        0.739009
#
#                                                     Learned Acc.
# fasttext_fasttext                                       0.940637
# results_dict,ShortDepPath,RuS,CV_,bin_,minFreq=...      0.910915
# RuS,lr=0.001,dropout=0.25,8epochs,rebalance=0,m...      0.922221
# results_dict,lemmas,RuS,TfIdf_,minFreq=1,_ngram...      0.918230

# %%
#this would be with unweighted voting

pd.Series(list(map(lambda x:x[0].item(),L_train.mean(axis=1)))).hist(bins=20)
plt.title('Unweighted voting for 12 classifiers')
# Out:
# Text(0.5,1,'Unweighted voting for 12 classifiers')

# %%
import math
import numpy as np
import scipy.sparse as sparse
from multiprocessing import Process, Queue
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from snorkel.models import FeatureKey, GoldLabel, Sentence, Span, Candidate
from snorkel.learning.utils import print_scores

def majority_vote(L):
    '''Majority vote'''
    pred = L.sum(axis=1)
    pred[(pred > 0).nonzero()[0]] = 1
    pred[(pred < 0).nonzero()[0]] = 0
    return pred

def majority_vote_score(L, gold_labels):
    
    y_pred = np.ravel(majority_vote(L))
    y_true = gold_labels.todense()
    y_true = [1 if y_true[i] == 1 else 0 for i in range(y_true.shape[0])]
    
    pos,neg = y_true.count(1),float(y_true.count(0))
    print "pos/neg    {:d}:{:d} {:.1f}%/{:.1f}%".format(int(pos), int(neg), pos/(pos+neg)*100, neg/(pos+neg)*100)
    print "precision  {:.2f}".format( 100 * precision_score(y_true, y_pred) )
    print "recall     {:.2f}".format( 100 * recall_score(y_true, y_pred) )
    print "f1         {:.2f}".format( 100 * f1_score(y_true, y_pred) )
    #print "accuracy  {:.2f}".format( 100 * accuracy_score(y_true, y_pred)

# %%
majority_vote_score(L_dev, L_gold_dev)
# Out:
# pos/neg    705:2525 21.8%/78.2%
# precision  67.84
# recall     54.75
# f1         60.60

# %%
#

# %%
L_dev.
# Out:
# <1x4 sparse matrix of type '<type 'numpy.int64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %%
l_i = L_dev[0].tocoo()

# %%
l_i.data[0]
# Out:
# -1

# %%
l_i.col[3]
# Out:
# 3

# %%
logp_false = e^10
logp_true = e

# %%
1 / (1 + np.exp(logp_false - logp_true))

# %%
gen_model.weights.dep_similar
# Out:
# <4x4 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## save probabilistic labels for the LSTM  -  this is the # of train. examples our LSTM will train on

# %%
from snorkel.annotations import save_marginals
save_marginals(session, L_train, train_marginals)
# Out:
# Saved 79400 marginals

# %%
plt.hist(train_marginals, bins=20)
plt.title('Histogram of probabilistic labels (created with %i models & LF_prior=True, LF_propensity=False)'%n_models)
plt.show()

# %%
plt.hist(train_marginals_w_prior, bins=20)
plt.title('Histogram of probabilistic labels (created with %i models & LF_prior=True, LF_propensity=False)'%n_models)
plt.show()

# %% [markdown]
# # ~~

# %%
L_test = labeler.apply_existing(split=2)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%

# %%
# load from db gold labels
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)
L_gold_test
# Out:
# <13350x1 sparse matrix of type '<type 'numpy.int64'>'
# 	with 5781 stored elements in Compressed Sparse Row format>

# %%
_ = gen_model.error_analysis(session, L_test, L_gold_test)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.259
# Neg. class accuracy: 0.975
# Precision            0.57
# Recall               0.259
# F1                   0.356
# ----------------------------------------
# TP: 388 | FP: 293 | TN: 11557 | FN: 1112
# ========================================

# %%
L_test.lf_stats(session, L_gold_test, gen_model.learned_lf_stats()['Accuracy'])
# Out:
#                     j  Coverage  Overlaps  Conflicts   TP   FP    FN    TN  \
# dummy               0  1.000000  0.433034   0.128764    0    0  1500  4281
# LogisticRegression  1  0.433034  0.433034   0.128764  683  563   817  3718
# SVC_linear          2  0.433034  0.433034   0.128764  594  592   906  3689
# SVC_rbf_C100        3  0.433034  0.433034   0.128764  606  500   894  3781
# SVC_rbf_C500        4  0.433034  0.433034   0.128764  625  484   875  3797
# SVC_rbf_C1000       5  0.433034  0.433034   0.128764  577  480   923  3801
#
#                     Empirical Acc.  Learned Acc.
# dummy                     0.740529      0.936173
# LogisticRegression        0.761287      0.893057
# SVC_linear                0.740875      0.888321
# SVC_rbf_C100              0.758865      0.893826
# SVC_rbf_C500              0.764920      0.897841
# SVC_rbf_C1000             0.757308      0.899282
